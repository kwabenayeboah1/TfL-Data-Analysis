# %% [markdown]
# In this Jupyter Notebook, we will be creating an interactive Map that includes data from a particular year for accidents recorded by TfL.
#
# This Map can consolidate multiple years into a single view that provides layers to differentiate between the Borough(s) and the Year(s) - or it can be used to focus on a particular year.
#
# This data was provided using the TfL API (https://api.tfl.gov.uk/) - This particular series of cells contain all the information for the earliest recorded year (2005).
#
# The JSON Responses for 2005 and 2006 have been provided within the Repo to begin with, please feel free to explore the cells below to gain an understanding of how the script runs, before attempting to get data on latter years.
#
# The following API Call can be made to obtain subsequent data. This cell also provides a progress bar that shows how much data is being downloaded.

# %%
import requests
import json
from tqdm import tqdm

# URL must include the year we'd like to download. 
# Right now it is configured to 2007.
url = "https://api.tfl.gov.uk/AccidentStats/2007"  # URL with the year in it

# Extract the year from the URL (assuming it's always at the end after the last slash)
year = url.split('/')[-1]

# Initiate the GET request with stream=True
response = requests.get(url, stream=True)

# Check if the request was successful
if response.status_code == 200:
    # Calculate the total size of the content
    total_size = int(response.headers.get('Content-Length', 0))
    
    # Create a progress bar
    with tqdm(total=total_size, unit='B', unit_scale=True) as bar:
        # Open the JSON file and write data as it is downloaded
        data = []
        for chunk in response.iter_content(chunk_size=1024):
            data.append(chunk)
            bar.update(len(chunk))  # Update the progress bar with the downloaded chunk
    
    # Join all chunks together and decode
    data = b''.join(data)  # Join all chunks together into one byte object
    data_str = data.decode('utf-8')  # Decode to string

    # Parse the JSON manually from the byte data
    json_data = json.loads(data_str)  # Parse the JSON from the string
    
    # Save the JSON data to a file with the year in the name
    file_name = f'response_{year}.json'  # Use f-string to include the year
    with open(file_name, 'w') as json_file:
        json.dump(json_data, json_file, indent=4)  # Save it as a pretty-printed JSON file
    
    print(f"JSON data saved to '{file_name}'.")
else:
    print(f"Error: {response.status_code}")

# %% [markdown]
# The following cell can be used to count the number of records within the JSON for reconciliation purposes once analysis has been performed.
#
# The Map is designed to plot incidents that contain the releveant geographic data (Lon/Lat co-ordinates) the absence of this data means the incident hasn't been logged with the appropriate co-ords at the time of recording.
#
# Reconciling figures after data has been plotted gives an idea as to the completeness of the data.

# %%
# Counts the number of records within a JSON so we can upload the full records to the map
record_count = 0

# Load JSON data
# This is the JSON that contains the necessary geographic data to map the accidents.
with open('response.json', 'r') as f:
    data = json.load(f)

    # Iterate over the elements of the JSON object
    for element in data:
        try:
            # Increment record counter for each element
            record_count += 1
            
            # Print the keys of the element
            if isinstance(element, dict):
                continue
            else:
                print("Element is not a dictionary.")
        
        except Exception as e:
            print("Error:", e)

# Print total number of records
print("Total number of records:", record_count)

# %% [markdown]
# We are using the Python Package 'Folium' to produce the HTML Map.
#
# I have added additional settings here to ensure we make the most of the data we have downloaded via the API.
#
# I also ensured that the clusters are interactive, to provide a clean UI which changes depending on the zoom level.
#
# This latest iteration includes a layer, meaning you can filter between the borugh level as well as the years (if the Map contains data from more than one year).

# %%
# Final Version - V6 - WE DID ITTT
# Removed clutter from the script
# Determined fix for the pop-ups that weren't working
# Added floating summary box and toggle for it.
# Currently the version we will be taking forward
# Contains fix for missing vehicles in counter
# Compare with the V5 script to ensure everything has been copied over accordingly.

import folium
from folium.plugins import MarkerCluster
import pandas as pd
from collections import Counter
import glob
from datetime import datetime
from branca.element import Html, MacroElement
from folium.elements import JSCSSMixin
import json
from jinja2 import Template

# Initialize the map
m = folium.Map(location=[51.5074, -0.1278], zoom_start=12)  # London coordinates

# Create a MarkerCluster layer
marker_cluster = MarkerCluster(name="Incident Marker", disableClusteringAtZoom=17).add_to(m)

# Extract latitude, longitude, severity, and vehicle information and save them to a list of dictionaries
incident_data = []  # List to store all relevant incident data
incomplete_data = []  # List to store incomplete data
incomplete_df = pd.DataFrame()  # DataFrame to store incomplete data
processed_years = []

# Counters for casualties, vehicles, and incomplete casualty data
casualty_counter = Counter()
vehicle_counter = Counter()

# Initialize a dictionary to store incident counts by borough and severity breakdowns
borough_incidents = {}
borough_severity_counter = {
    'Fatal': Counter(),
    'Serious': Counter(),
    'Slight': Counter()
}

# Load GeoJSON data for borough boundaries
with open('london_boroughs.geojson', 'r') as f:
    borough_geojson = json.load(f)

# Generate colors for years (this includes a color for each year dynamically)
year_colors = [
    "red", "blue", "green", "purple", "orange", "brown", "pink", "cyan", "yellow", "gray",
    "lightgreen", "darkblue", "indigo", "magenta", "violet", "gold", "lime", "teal", "navy", 
    "aqua", "fuchsia", "salmon", "crimson", "chartreuse", "skyblue", "tan", "coral"]

year_color_map = {}

# Function to determine the marker style
def get_marker_style(year, severity):
    # Map each year to a color, cycling through the available year_colors
    year_color = year_color_map.get(year, 'black')  # Default to black if year is not found
    severity_colors = {
        'Fatal': 'darkred', 'Serious': 'red', 'Slight': 'orange'
    }
    severity_color = severity_colors.get(severity, 'gray')

    return year_color, severity_color


# Function to calculate the color of the borough based on the severity percentages
def get_borough_color(borough):
    if borough not in borough_incidents:
        return "green"  # Default color if no incidents
    total_borough_incidents = borough_incidents[borough]
    
    fatal_pct = (borough_severity_counter['Fatal'][borough] / total_borough_incidents) * 100 if total_borough_incidents else 0
    serious_pct = (borough_severity_counter['Serious'][borough] / total_borough_incidents) * 100 if total_borough_incidents else 0
    slight_pct = (borough_severity_counter['Slight'][borough] / total_borough_incidents) * 100 if total_borough_incidents else 0

    if fatal_pct > 10:
        return "darkred"
    elif serious_pct > 30:
        return "red"
    elif slight_pct > 50:
        return "orange"
    else:
        return "green"

# Process multiple response JSON files using glob
data_files = glob.glob('response_*.json')

# Following line can be commented out if you are looking to create a map with multiple years, this variable lets you select specific JSONs using Index.
# data_files = [data_files[0]]  # Defaulted to select the first file if multiple response jsons exist - Can be used to select individual files for focused maps.

for file in data_files:
    year = file.split('_')[1].split('.')[0]  # Extract year from filename
    processed_years.append(year)  # Store year for filename generation

# Set year color mapping for each unique year found
for year in processed_years:
    if year not in year_color_map:
        year_color_map[year] = year_colors[len(year_color_map) % len(year_colors)]

for file in data_files:
    with open(file, 'r') as f:
        data = json.load(f)
        if isinstance(data, list):  # Ensure the loaded data is a list
            for record in data:
                lat = record.get('lat')
                lon = record.get('lon')
                location = record.get('location')
                date = record.get('date')
                borough = record.get('borough')
                severity = record.get('severity')
                vehicles = record.get('vehicles')
                casualties = record.get('casualties')
                
                year = date.split("-")[0] if date and "-" in date else "Unknown Year"
                
                # Log incomplete data if required fields are missing
                if lat is not None and lon is not None and severity is not None:
                    if borough:
                        if borough not in borough_incidents:
                            borough_incidents[borough] = 0
                        borough_incidents[borough] += 1
                        borough_severity_counter[severity][borough] += 1
                    else:
                        incomplete_data.append(record)  # Log incomplete data
                        continue

                    vehicles_flat = [vehicle['type'] for vehicle in vehicles] if vehicles else []

                    if casualties:
                        for casualty in casualties:
                            age = casualty.get('age')
                            class_ = casualty.get('class')
                            mode = casualty.get('mode')
                            if all([age, class_, mode]):
                                casualty_counter.update([(age, class_, mode)])
                            else:
                                incomplete_data.append(casualty)  # Store incomplete casualty data

                    if vehicles:
                        vehicle_types = [vehicle['type'] for vehicle in vehicles]
                        vehicle_counter.update(vehicle_types)

                    incident_data.append({
                        'lat': lat,
                        'lon': lon,
                        'severity': severity,
                        'vehicles': vehicles_flat,
                        'casualties': casualties,
                        'id': record.get('id'),
                        'location': location,
                        'date': date,
                        'borough': borough
                    })

# Process the incomplete data into a dataframe
incomplete_df = pd.DataFrame(incomplete_data)

# Calculate the total number of incidents for percentage calculation
total_incidents = len(incident_data)

# Function to format the date in a readable way
def format_date(date_string):
    try:
        # Parse the ISO 8601 format (e.g., '2017-05-22T13:12:00Z')
        dt = datetime.strptime(date_string, '%Y-%m-%dT%H:%M:%SZ')
        # Format to 'Month Day, Year, Hour:Minute'
        return dt.strftime('%b %d, %Y, %H:%M')
    except ValueError:
        return "Invalid date format"

# Set to track unique IDs
existing_ids = set()

for index, incident in enumerate(incident_data):
    lat = incident['lat']
    lon = incident['lon']
    severity = incident['severity']
    vehicles = incident['vehicles']
    year = incident['date'].split("-")[0] if incident['date'] and "-" in incident['date'] else "Unknown Year"
    year_color, severity_color = get_marker_style(year, severity)

    # Get incident ID, or generate one if missing/duplicate
    incident_id = incident.get('id', f"generated_{index}")

    # Ensure uniqueness
    if incident_id in existing_ids:
        incident_id = f"{incident_id}_{index}"  # Append index to make it unique

    existing_ids.add(incident_id)

    # Format the date
    formatted_date = format_date(incident.get('date', 'N/A'))

    # Popup Information
    popup_text = f"<b style='color:{year_color};'>Year: {year}</b><br>"
    popup_text += f"ID: {incident_id}<br>"  # Use the unique ID
    popup_text += f"Severity: <b style='color:{severity_color};'>{severity}</b><br>"
    popup_text += f"Date: {formatted_date}<br>"
    popup_text += f"Location: {incident.get('location', 'N/A')}<br>"
    popup_text += f"Borough: {incident.get('borough', 'N/A')}<br>"

    if vehicles:
        popup_text += f"Vehicles involved:<br>{',  '.join(vehicles)}"
    else:
        popup_text += "No vehicle information available"

    # Add marker
    folium.CircleMarker(
        location=[lat, lon],
        radius=7,
        color=year_color,
        fill=True,
        fill_color=severity_color,
        fill_opacity=0.8,
        popup=popup_text
    ).add_to(marker_cluster)

# Adding incomplete data with a gray marker
for record in incomplete_data:
    lat = record.get('lat')
    lon = record.get('lon')

    if lat is not None and lon is not None:
        folium.CircleMarker(
            location=[lat, lon],
            radius=5,
            color='gray',
            fill=True,
            fill_color='gray',
            fill_opacity=0.8,
            popup="Incomplete Data"
        ).add_to(marker_cluster)

# Add borough polygons with severity coloring and percentage
borough_layer = folium.FeatureGroup(name="Borough Severity")
for feature in borough_geojson['features']:
    borough_name = feature['properties']['name']
    total_borough_incidents = borough_incidents.get(borough_name, 0)
    fatal_pct = (borough_severity_counter['Fatal'].get(borough_name, 0) / total_borough_incidents) * 100 if total_borough_incidents else 0
    serious_pct = (borough_severity_counter['Serious'].get(borough_name, 0) / total_borough_incidents) * 100 if total_borough_incidents else 0
    slight_pct = (borough_severity_counter['Slight'].get(borough_name, 0) / total_borough_incidents) * 100 if total_borough_incidents else 0
    
    borough_color = get_borough_color(borough_name)

    popup_text = f"<strong>{borough_name}</strong><br>"
    popup_text += f"Incidents: {total_borough_incidents}<br>"
    popup_text += f"Fatal: {borough_severity_counter['Fatal'].get(borough_name, 0)} ({fatal_pct:.2f}%)<br>"
    popup_text += f"Serious: {borough_severity_counter['Serious'].get(borough_name, 0)} ({serious_pct:.2f}%)<br>"
    popup_text += f"Slight: {borough_severity_counter['Slight'].get(borough_name, 0)} ({slight_pct:.2f}%)<br>"

    folium.GeoJson(
        feature,
        style_function=lambda x, color=borough_color: {
            'fillColor': color,
            'fillOpacity': 0.6,
            'color': 'black',
            'weight': 2
        },
        tooltip=popup_text
    ).add_to(borough_layer)

borough_layer.add_to(m)

# Add the layer control (toggle between borough and incident markers)
folium.LayerControl().add_to(m)

summary_html = """
<div id="incident-summary" style="
    position: fixed; bottom: 50px; left: 50px; 
    width: 260px; background: rgba(255, 255, 255, 0.9); 
    padding: 12px; border-radius: 8px; 
    z-index: 1000; font-size: 14px; 
    box-shadow: 3px 3px 10px rgba(0,0,0,0.2);
    border-left: 5px solid #007bff;
    display: block;">

    <h4 style="margin: 5px 0; font-size: 16px; text-align: center; color: #007bff;">🚦 London Incident Summary</h4>
    <hr style="border: 0; height: 1px; background: #ddd; margin: 8px 0;">
    <p><strong>Total Incidents:</strong> {total_incidents:,}</p>
    <p><strong><span style="color: red;">Fatal:</span></strong> {total_fatal:,} ({fatal_pct:.2f}%)</p>
    <p><strong><span style="color: orange;">Serious:</span></strong> {total_serious:,} ({serious_pct:.2f}%)</p>
    <p><strong><span style="color: green;">Slight:</span></strong> {total_slight:,} ({slight_pct:.2f}%)</p>

</div>

<button onclick="toggleSummary()" style="
    position: fixed; bottom: 10px; right: 10px; 
    background: #007bff; color: white; border: none; 
    padding: 6px 12px; border-radius: 6px; 
    cursor: pointer; box-shadow: 2px 2px 5px rgba(0,0,0,0.2);
    z-index: 1001;">ℹ️ Toggle Overview</button>


<script>
function toggleSummary() {{
    var panel = document.getElementById('incident-summary');
    if (panel.style.display === 'none') {{
        panel.style.display = 'block';
    }} else {{
        panel.style.display = 'none';
    }}
}}
</script>
""".format(
    total_incidents=total_incidents,
    total_fatal=total_fatal,
    fatal_pct=fatal_pct,
    total_serious=total_serious,
    serious_pct=serious_pct,
    total_slight=total_slight,
    slight_pct=slight_pct
)

class FloatInfoPanel(JSCSSMixin, MacroElement):
    def __init__(self, html):
        super().__init__()
        self._name = "FloatInfoPanel"
        self.html = html
    def render(self, **kwargs):
        return self.html
m.get_root().html.add_child(FloatInfoPanel(summary_html))

# Add HTML to the map
macro = MacroElement()
macro._template = Template(summary_html)
m.get_root().add_child(macro)

# Generate the map filename dynamically
year_range = "_".join(processed_years)
map_filename = f"TfL_Incident_Map_{year_range}.html"

# Save the map
m.save("map_filename")
print('Saving Map ...')
print(f"Map saved as '{map_filename}'")
print('Loading Map ...')

#Display Map in-line (Console View)
m

# %% [markdown]
# # Statistics
#
# - These contain various statistics that can be used to understand the breadth of data provided by the JSON.

# %% [markdown]
# Missing Data Report - This can be used to reconcile figures as not every incident can be plotted due to missing coordinates data.
#
# Where the incident is available with geo co-ordinates but missing details, this will be shown on the map with a 'Grey' Icon as per the logic of the script.
#
# Where the relevant co-ordinates are missing, they will simply be logged as 'Incomplete' within this script.

# %%
import pandas as pd
import json
import glob
import os
from collections import Counter

# Initialize DataFrame for incomplete data
incomplete_data = []
incomplete_df = pd.DataFrame()

# Initialize counters for incomplete fields
missing_field_counts = {
    'lat': 0,
    'lon': 0,
    'severity': 0,
    'borough': 0,
    'vehicles': 0,
    'casualties': 0
}

# Process multiple response JSON files
data_files = glob.glob('response_*.json')
for file in data_files:
    with open(file, 'r') as f:
        data = json.load(f)
        if isinstance(data, list):  # Ensure the loaded data is a list
            for record in data:
                lat = record.get('lat')
                lon = record.get('lon')
                severity = record.get('severity')
                borough = record.get('borough')
                vehicles = record.get('vehicles')
                casualties = record.get('casualties')
                
                # Check for missing fields and log them
                if lat is None:
                    missing_field_counts['lat'] += 1
                if lon is None:
                    missing_field_counts['lon'] += 1
                if severity is None:
                    missing_field_counts['severity'] += 1
                if borough is None:
                    missing_field_counts['borough'] += 1
                if vehicles is None:
                    missing_field_counts['vehicles'] += 1
                if casualties is None:
                    missing_field_counts['casualties'] += 1

                # Log incomplete data
                if lat is None or lon is None or severity is None or borough is None:
                    incomplete_data.append(record)

# Convert incomplete data to DataFrame
incomplete_df = pd.DataFrame(incomplete_data)

# Generate the missing data report
total_records = len(data)  # Assuming 'data' is a list containing all records
missing_report = {
    'Field': [],
    'Total Records': [],
    'Missing Records': [],
    'Missing Percentage': []
}

for field, count in missing_field_counts.items():
    missing_report['Field'].append(field)
    missing_report['Total Records'].append(total_records)
    missing_report['Missing Records'].append(count)
    missing_report['Missing Percentage'].append((count / total_records) * 100 if total_records > 0 else 0)

# Convert the report into a DataFrame
missing_report_df = pd.DataFrame(missing_report)

# Save the report as a CSV file
# missing_report_df.to_csv('missing_data_report.csv', index=False)

# Output the report
print("Missing Data Report saved as 'missing_data_report.csv'")
print(missing_report_df)
# Out:
# Missing Data Report saved as 'missing_data_report.csv'
#         Field  Total Records  Missing Records  Missing Percentage
# 0         lat          53484                0                 0.0
# 1         lon          53484                0                 0.0
# 2    severity          53484                0                 0.0
# 3     borough          53484                0                 0.0
# 4    vehicles          53484                0                 0.0
# 5  casualties          53484                0                 0.0

# %%
# Find the borough with the highest incidents for each severity
highest_fatal_borough = max(borough_severity_counter.get("Fatal", {}).items(), key=lambda x: x[1], default=(None, 0))
highest_serious_borough = max(borough_severity_counter.get("Serious", {}).items(), key=lambda x: x[1], default=(None, 0))
highest_slight_borough = max(borough_severity_counter.get("Slight", {}).items(), key=lambda x: x[1], default=(None, 0))

# Print the highest statistics with comma separators
print(f"Highest Number of Fatal Incidents: {highest_fatal_borough[0]:<25} | Fatal: {highest_fatal_borough[1]:,}")
print(f"Highest Number of Serious Incidents: {highest_serious_borough[0]:<25} | Serious: {highest_serious_borough[1]:,}")
print(f"Highest Number of Slight Incidents: {highest_slight_borough[0]:<25} | Slight: {highest_slight_borough[1]:,}")
print("-" * 106)

# Now, print the remaining boroughs with percentages in respect to the total incidents in each borough
for borough in boroughs:
    fatal = borough_severity_counter.get("Fatal",{}).get(borough, 0)
    serious = borough_severity_counter.get("Serious",{}).get(borough, 0)
    slight = borough_severity_counter.get("Slight",{}).get(borough, 0)
    
    # Total incidents in the borough
    total_incidents_in_borough = fatal + serious + slight

    # Calculate percentages for each severity
    fatal_percentage = (fatal / total_incidents_in_borough) * 100 if total_incidents_in_borough > 0 else 0
    serious_percentage = (serious / total_incidents_in_borough) * 100 if total_incidents_in_borough > 0 else 0
    slight_percentage = (slight / total_incidents_in_borough) * 100 if total_incidents_in_borough > 0 else 0

    # Print the borough statistics with percentage calculations
    print(f"{borough:<25} | Fatal: {fatal:>6,} | {fatal_percentage:>6.2f}% | Serious: {serious:>6,} | {serious_percentage:>6.2f}% | Slight: {slight:>6,} | {slight_percentage:>6.2f}%")
# Out:
# Highest Number of Fatal Incidents: Hounslow                  | Fatal: 26
# Highest Number of Serious Incidents: City of Westminster       | Serious: 466
# Highest Number of Slight Incidents: City of Westminster       | Slight: 2,640
# ----------------------------------------------------------------------------------------------------------
# City of London            | Fatal:      2 |   0.32% | Serious:     78 |  12.54% | Slight:    542 |  87.14%
# Camden                    | Fatal:      4 |   0.21% | Serious:    252 |  13.48% | Slight:  1,614 |  86.31%
# City of Westminster       | Fatal:     22 |   0.70% | Serious:    466 |  14.90% | Slight:  2,640 |  84.40%
# Tower Hamlets             | Fatal:     16 |   0.95% | Serious:    194 |  11.56% | Slight:  1,468 |  87.49%
# Southwark                 | Fatal:     10 |   0.49% | Serious:    240 |  11.79% | Slight:  1,786 |  87.72%
# Hammersmith and Fulham    | Fatal:     20 |   1.37% | Serious:    206 |  14.11% | Slight:  1,234 |  84.52%
# Islington                 | Fatal:      8 |   0.54% | Serious:    160 |  10.83% | Slight:  1,310 |  88.63%
# Redbridge                 | Fatal:     14 |   0.85% | Serious:    160 |   9.70% | Slight:  1,476 |  89.45%
# Newham                    | Fatal:      4 |   0.24% | Serious:    150 |   8.94% | Slight:  1,524 |  90.82%
# Sutton                    | Fatal:      4 |   0.39% | Serious:    122 |  11.96% | Slight:    894 |  87.65%
# Hillingdon                | Fatal:     14 |   0.78% | Serious:    196 |  10.96% | Slight:  1,578 |  88.26%
# Brent                     | Fatal:     14 |   0.74% | Serious:    212 |  11.13% | Slight:  1,678 |  88.13%
# Enfield                   | Fatal:     24 |   1.23% | Serious:    200 |  10.25% | Slight:  1,728 |  88.52%
# Greenwich                 | Fatal:     14 |   0.88% | Serious:    188 |  11.78% | Slight:  1,394 |  87.34%
# Bexley                    | Fatal:     12 |   1.11% | Serious:    154 |  14.23% | Slight:    916 |  84.66%
# Lambeth                   | Fatal:     16 |   0.68% | Serious:    296 |  12.59% | Slight:  2,040 |  86.73%
# Merton                    | Fatal:      2 |   0.21% | Serious:    128 |  13.70% | Slight:    804 |  86.08%
# Harrow                    | Fatal:      6 |   0.60% | Serious:    126 |  12.50% | Slight:    876 |  86.90%
# Havering                  | Fatal:     12 |   0.83% | Serious:    128 |   8.90% | Slight:  1,298 |  90.26%
# Kensington and Chelsea    | Fatal:     20 |   1.30% | Serious:    204 |  13.21% | Slight:  1,320 |  85.49%
# Bromley                   | Fatal:     18 |   1.05% | Serious:    226 |  13.19% | Slight:  1,470 |  85.76%
# Ealing                    | Fatal:     16 |   0.72% | Serious:    220 |   9.93% | Slight:  1,980 |  89.35%
# Kingston                  | Fatal:      6 |   0.80% | Serious:    108 |  14.48% | Slight:    632 |  84.72%
# Richmond upon Thames      | Fatal:      4 |   0.42% | Serious:    124 |  13.16% | Slight:    814 |  86.41%
# Barnet                    | Fatal:     24 |   1.06% | Serious:    250 |  10.99% | Slight:  2,000 |  87.95%
# Hackney                   | Fatal:      8 |   0.44% | Serious:    210 |  11.68% | Slight:  1,580 |  87.88%
# Barking and Dagenham      | Fatal:     12 |   1.10% | Serious:     84 |   7.73% | Slight:    990 |  91.16%
# Wandsworth                | Fatal:      8 |   0.46% | Serious:    228 |  13.03% | Slight:  1,514 |  86.51%
# Waltham Forest            | Fatal:     10 |   0.64% | Serious:    150 |   9.65% | Slight:  1,394 |  89.70%
# Hounslow                  | Fatal:     26 |   1.57% | Serious:    186 |  11.22% | Slight:  1,446 |  87.21%
# Croydon                   | Fatal:     14 |   0.61% | Serious:    272 |  11.92% | Slight:  1,996 |  87.47%
# Haringey                  | Fatal:     14 |   0.99% | Serious:    164 |  11.58% | Slight:  1,238 |  87.43%
# Lewisham                  | Fatal:     12 |   0.66% | Serious:    258 |  14.10% | Slight:  1,560 |  85.25%

# %%
for severity, boroughs in borough_severity_counter.items():
    max_borough = max(boroughs, key=boroughs.get)
    min_borough = min(boroughs, key=boroughs.get)
    max_value = boroughs[max_borough]
    min_value = boroughs[min_borough]

    print(f"{severity} Accidents:")
    print(f"  - Most Incidents: {max_borough} ({max_value})")
    print(f"  - Least Incidents: {min_borough} ({min_value})")
    print()
# Out:
# Fatal Accidents:
#   - Most Incidents: Hounslow (26)
#   - Least Incidents: City of London (2)
#
# Serious Accidents:
#   - Most Incidents: City of Westminster (466)
#   - Least Incidents: City of London (78)
#
# Slight Accidents:
#   - Most Incidents: City of Westminster (2640)
#   - Least Incidents: City of London (542)

# %%
# Step 1: Calculate total incidents per borough
total_borough_counts = {}

for severity, boroughs in borough_severity_counter.items():
    for borough, count in boroughs.items():
        total_borough_counts[borough] = total_borough_counts.get(borough, 0) + count

# Step 2: Calculate the grand total of all incidents
grand_total = sum(total_borough_counts.values())

# Step 3: Rank Boroughs by Highest to Lowest Incidents and calculate percentages
sorted_boroughs = sorted(total_borough_counts.items(), key=lambda x: x[1], reverse=True)

# Determine max lengths for formatting
max_borough_len = max(len(borough) for borough in total_borough_counts.keys())

# Print clean formatted rankings
print(f"{'Borough':<{max_borough_len}} | {'Incidents':>9} | {'Percentage':>9}")
print("-" * (max_borough_len + 25))  # Dynamic separator

for borough, count in sorted_boroughs:
    percentage = (count / grand_total) * 100  # Calculate the percentage
    print(f"{borough:<{max_borough_len}} | {count:>9,} | {percentage:>8.2f}%")
# Out:
# Borough                | Incidents | Percentage
# -----------------------------------------------
# City of Westminster    |     3,128 |     5.85%
# Lambeth                |     2,352 |     4.40%
# Croydon                |     2,282 |     4.27%
# Barnet                 |     2,274 |     4.25%
# Ealing                 |     2,216 |     4.14%
# Southwark              |     2,036 |     3.81%
# Enfield                |     1,952 |     3.65%
# Brent                  |     1,904 |     3.56%
# Camden                 |     1,870 |     3.50%
# Lewisham               |     1,830 |     3.42%
# Hackney                |     1,798 |     3.36%
# Hillingdon             |     1,788 |     3.34%
# Wandsworth             |     1,750 |     3.27%
# Bromley                |     1,714 |     3.20%
# Tower Hamlets          |     1,678 |     3.14%
# Newham                 |     1,678 |     3.14%
# Hounslow               |     1,658 |     3.10%
# Redbridge              |     1,650 |     3.09%
# Greenwich              |     1,596 |     2.98%
# Waltham Forest         |     1,554 |     2.91%
# Kensington and Chelsea |     1,544 |     2.89%
# Islington              |     1,478 |     2.76%
# Hammersmith and Fulham |     1,460 |     2.73%
# Havering               |     1,438 |     2.69%
# Haringey               |     1,416 |     2.65%
# Barking and Dagenham   |     1,086 |     2.03%
# Bexley                 |     1,082 |     2.02%
# Sutton                 |     1,020 |     1.91%
# Harrow                 |     1,008 |     1.88%
# Richmond upon Thames   |       942 |     1.76%
# Merton                 |       934 |     1.75%
# Kingston               |       746 |     1.39%
# City of London         |       622 |     1.16%

# %%
from collections import Counter

# Step 1: Calculate total vehicle count
total_vehicle_count = sum(vehicle_counter.values())

# Step 2: Sort vehicles by count (descending)
sorted_vehicles = sorted(vehicle_counter.items(), key=lambda x: x[1], reverse=True)

# Step 3: Find the most common vehicle
most_common_vehicle, most_common_count = sorted_vehicles[0]

# Determine max length for formatting
max_vehicle_len = max(len(vehicle) for vehicle in vehicle_counter.keys())

# Print clean formatted vehicle counts
print(f"{'Vehicle Type':<{max_vehicle_len}} | {'Incidents':>9} | {'Percentage':>9}")
print("-" * (max_vehicle_len + 25))  # Dynamic separator

for vehicle, count in sorted_vehicles:
    percentage = (count / total_vehicle_count) * 100  # Calculate the percentage
    print(f"{vehicle:<{max_vehicle_len}} | {count:>9,} | {percentage:>8.2f}%")

# Step 4: Print additional insights
print("-" * 46)
print("Total Vehicle Count:", f"{total_vehicle_count:,}")
print(f"Most Common Vehicle: {most_common_vehicle} ({most_common_count:,} incidents)")
# Out:
# Vehicle Type          | Incidents | Percentage
# ----------------------------------------------
# Car                   |    64,548 |    66.89%
# PedalCycle            |     5,982 |     6.20%
# BusOrCoach            |     5,364 |     5.56%
# LightGoodsVehicle     |     4,660 |     4.83%
# Motorcycle_500cc_Plus |     3,122 |     3.24%
# Motorcycle_50_125cc   |     2,794 |     2.90%
# Motorcycle_0_50cc     |     2,780 |     2.88%
# Motorcycle_125_500cc  |     2,556 |     2.65%
# Taxi                  |     1,666 |     1.73%
# HeavyGoodsVehicle     |     1,216 |     1.26%
# OtherMotorVehicle     |       864 |     0.90%
# MediumGoodsVehicle    |       642 |     0.67%
# Minibus               |       244 |     0.25%
# AgriculturalVehicle   |        30 |     0.03%
# OtherNonMotorVehicle  |        12 |     0.01%
# TramOrLightRail       |        12 |     0.01%
# RiddenHorse           |         6 |     0.01%
# GoodsVehicle          |         2 |     0.00%
# ----------------------------------------------
# Total Vehicle Count: 96,500
# Most Common Vehicle: Car (64,548 incidents)

# %%
# Initialize counter
vehicle_severity_counter = {}

# Process each incident
for incident in incident_data:
    severity = incident["severity"]  # Get severity level
    vehicles = set(incident["vehicles"])  # Use a set to remove duplicates

    for vehicle in vehicles:
        if vehicle not in vehicle_severity_counter:
            vehicle_severity_counter[vehicle] = {'Fatal': 0, 'Serious': 0, 'Slight': 0}

        vehicle_severity_counter[vehicle][severity] += 1

# Determine max length for vehicle type formatting and ensure enough space
max_vehicle_len = max(len(vehicle) for vehicle in vehicle_severity_counter.keys())

# Define column width for other columns (Fatal, Serious, Slight) and adjust Total column width
column_width = 15

# Format header with dynamic alignment (centered for headings)
print("\nVehicle Severity Breakdown:")
print(f"{'Vehicle Type':^{max_vehicle_len}} | {'Fatal':^{column_width}} | {'Serious':^{column_width}} | {'Slight':^{column_width}} | {'Total':^{column_width + 3}}")  # Added extra space to total
print("-" * (max_vehicle_len + 4 + 4 * column_width + 4))  # Adjusted for Total column width

# Initialize totals for Fatal, Serious, Slight, and Total
total_fatal = total_serious = total_slight = total_incidents = 0

# Sort and print
sorted_vehicles = sorted(vehicle_severity_counter.items(), key=lambda x: sum(x[1].values()), reverse=True)

for vehicle, severity_counts in sorted_vehicles:
    total = sum(severity_counts.values())
    total_fatal += severity_counts['Fatal']
    total_serious += severity_counts['Serious']
    total_slight += severity_counts['Slight']
    total_incidents += total

    # Calculate percentage per severity type relative to the total incidents for that vehicle
    fatal_pct = (severity_counts['Fatal'] / total) * 100 if total > 0 else 0
    serious_pct = (severity_counts['Serious'] / total) * 100 if total > 0 else 0
    slight_pct = (severity_counts['Slight'] / total) * 100 if total > 0 else 0

    # Combine number and percentage in format: '954 (54%)'
    fatal_display = f"{severity_counts['Fatal']:,} ({fatal_pct:5.2f}%)"
    serious_display = f"{severity_counts['Serious']:,} ({serious_pct:5.2f}%)"
    slight_display = f"{severity_counts['Slight']:,} ({slight_pct:5.2f}%)"
    
    # Print each row with the Total column centered
    print(f"{vehicle:^{max_vehicle_len}} | {fatal_display:>{column_width}} | {serious_display:>{column_width}} | {slight_display:>{column_width}} | {total:^{column_width + 3},}")

# Print total row
total_fatal_display = f"{total_fatal:,}"
total_serious_display = f"{total_serious:,}"
total_slight_display = f"{total_slight:,}"
total_incidents_display = f"{total_incidents:,}"

print("-" * (max_vehicle_len + 4 + 4 * column_width + 4))
print(f"{'Total':^{max_vehicle_len}} | {total_fatal_display:>{column_width}} | {total_serious_display:>{column_width}} | {total_slight_display:>{column_width}} | {total_incidents_display:^{column_width + 3}}")
print("-" * (max_vehicle_len + 4 + 4 * column_width + 4))
# Out:
# Vehicle Severity Breakdown:
#     Vehicle Type      |      Fatal      |     Serious     |     Slight      |       Total
# -----------------------------------------------------------------------------------------
#          Car          |    248 ( 0.57%) |  4,752 (10.99%) | 38,230 (88.43%) |       43,230
#      PedalCycle       |     44 ( 0.74%) |    742 (12.47%) |  5,166 (86.79%) |       5,952
#      BusOrCoach       |     48 ( 0.91%) |    626 (11.82%) |  4,622 (87.27%) |       5,296
#   LightGoodsVehicle   |     34 ( 0.76%) |    460 (10.27%) |  3,984 (88.97%) |       4,478
# Motorcycle_500cc_Plus |     46 ( 1.49%) |    552 (17.85%) |  2,494 (80.66%) |       3,092
#  Motorcycle_50_125cc  |     22 ( 0.79%) |    430 (15.43%) |  2,334 (83.78%) |       2,786
#   Motorcycle_0_50cc   |     10 ( 0.36%) |    340 (12.30%) |  2,414 (87.34%) |       2,764
# Motorcycle_125_500cc  |     26 ( 1.02%) |    434 (17.10%) |  2,078 (81.88%) |       2,538
#         Taxi          |     10 ( 0.61%) |    204 (12.48%) |  1,420 (86.90%) |       1,634
#   HeavyGoodsVehicle   |     36 ( 3.10%) |    152 (13.10%) |    972 (83.79%) |       1,160
#   OtherMotorVehicle   |      2 ( 0.24%) |     98 (11.69%) |    738 (88.07%) |        838
#  MediumGoodsVehicle   |      2 ( 0.32%) |     72 (11.36%) |    560 (88.33%) |        634
#        Minibus        |      2 ( 0.83%) |     28 (11.57%) |    212 (87.60%) |        242
#  AgriculturalVehicle  |      2 ( 6.67%) |      8 (26.67%) |     20 (66.67%) |         30
# OtherNonMotorVehicle  |      0 ( 0.00%) |      4 (33.33%) |      8 (66.67%) |         12
#    TramOrLightRail    |      0 ( 0.00%) |      4 (33.33%) |      8 (66.67%) |         12
#      RiddenHorse      |      2 (50.00%) |      0 ( 0.00%) |      2 (50.00%) |         4
#     GoodsVehicle      |      0 ( 0.00%) |      0 ( 0.00%) |     2 (100.00%) |         2
# -----------------------------------------------------------------------------------------
#         Total         |             534 |           8,906 |          65,264 |       74,704
# -----------------------------------------------------------------------------------------

# %%
vehicle_casualties_counter = {}
for incident in incident_data:
    for vehicle in incident['vehicles']:
        if vehicle not in vehicle_casualties_counter:
            vehicle_casualties_counter[vehicle] = {'total': 0, 'drivers': 0, 'passengers': 0}
        for casualty in incident['casualties']:
            vehicle_casualties_counter[vehicle]['total'] += 1
            if casualty['class'] == 'Driver':
                vehicle_casualties_counter[vehicle]['drivers'] += 1
            else:
                vehicle_casualties_counter[vehicle]['passengers'] += 1


print(f"\nAverage Casualties Per Incident: {average_casualties_per_incident:.2f}")
total_casualties = sum(len(incident['casualties']) for incident in incident_data)
average_casualties_per_incident = total_casualties / len(incident_data) if incident_data else 0
# Print casualties count for each vehicle with improved formatting
print("\nCasualties by Vehicle Type:")
print("="*80)  # Separator for better visibility
for vehicle, casualty_counts in vehicle_casualties_counter.items():
    print(f"{vehicle: <25} | Drivers: {casualty_counts['drivers']: <6} | Passengers: {casualty_counts['passengers']: <6}| Total: {casualty_counts['total']: <6} ")
print("="*80)  # Separator at the end
# Out:
# Average Casualties Per Incident: 1.19
#
# Casualties by Vehicle Type:
# ================================================================================
# Car                       | Drivers: 54206  | Passengers: 27734 | Total: 81940
# Taxi                      | Drivers: 1130   | Passengers: 872   | Total: 2002
# PedalCycle                | Drivers: 5956   | Passengers: 220   | Total: 6176
# LightGoodsVehicle         | Drivers: 3774   | Passengers: 1866  | Total: 5640
# OtherMotorVehicle         | Drivers: 658    | Passengers: 396   | Total: 1054
# BusOrCoach                | Drivers: 1342   | Passengers: 5026  | Total: 6368
# Motorcycle_0_50cc         | Drivers: 2584   | Passengers: 406   | Total: 2990
# Motorcycle_50_125cc       | Drivers: 2644   | Passengers: 386   | Total: 3030
# Motorcycle_500cc_Plus     | Drivers: 3026   | Passengers: 494   | Total: 3520
# HeavyGoodsVehicle         | Drivers: 1118   | Passengers: 462   | Total: 1580
# Motorcycle_125_500cc      | Drivers: 2348   | Passengers: 464   | Total: 2812
# MediumGoodsVehicle        | Drivers: 558    | Passengers: 232   | Total: 790
# Minibus                   | Drivers: 170    | Passengers: 204   | Total: 374
# AgriculturalVehicle       | Drivers: 16     | Passengers: 14    | Total: 30
# OtherNonMotorVehicle      | Drivers: 12     | Passengers: 0     | Total: 12
# RiddenHorse               | Drivers: 10     | Passengers: 0     | Total: 10
# TramOrLightRail           | Drivers: 6      | Passengers: 12    | Total: 18
# GoodsVehicle              | Drivers: 2      | Passengers: 0     | Total: 2
# ================================================================================

# %%
severity_counter = {'Fatal': 0, 'Serious': 0, 'Slight': 0}
total_incidents = len(incident_data)

# Count severity distribution
for incident in incident_data:
    severity = incident['severity']
    severity_counter[severity] += 1

# Print severity distribution with percentages and sorted
print("\nSeverity Distribution of Incidents:")
print("="*50)  # Separator for better visibility
for severity, count in sorted(severity_counter.items(), key=lambda x: x[1], reverse=True):
    percentage = (count / total_incidents) * 100
    print(f"{severity: <10} | Count: {count: <6} | Percentage: {percentage: .2f}%")
print("="*50)  # Separator at the end
# Out:
# Severity Distribution of Incidents:
# ==================================================
# Slight     | Count: 46734  | Percentage:  87.38%
# Serious    | Count: 6340   | Percentage:  11.85%
# Fatal      | Count: 410    | Percentage:  0.77%
# ==================================================

# %%
# Initialize severity counter
severity_counter = {'Fatal': 0, 'Serious': 0, 'Slight': 0}
total_incidents = len(incident_data)

# Count severity distribution
for incident in incident_data:
    severity = incident['severity']
    severity_counter[severity] += 1

# Print severity distribution with percentages and sorted
print("\nSeverity Distribution of Incidents:")
print("="*50)  # Separator for better visibility
for severity, count in sorted(severity_counter.items(), key=lambda x: x[1], reverse=True):
    percentage = (count / total_incidents) * 100
    print(f"{severity: <10} | Count: {count: <6} | Percentage: {percentage: .2f}%")
    
# Print total for all severity types
total_fatal = severity_counter['Fatal']
total_serious = severity_counter['Serious']
total_slight = severity_counter['Slight']

# Calculate percentage breakdown for total severity
fatal_percentage = (total_fatal / total_incidents) * 100 if total_incidents > 0 else 0
serious_percentage = (total_serious / total_incidents) * 100 if total_incidents > 0 else 0
slight_percentage = (total_slight / total_incidents) * 100 if total_incidents > 0 else 0

# Print total summary
print("="*117)  # Separator for better visibility
print(f"Total Incidents   | Count: {total_incidents: <6} | Fatal: {total_fatal: <6} ({fatal_percentage: .2f}%) | Serious: {total_serious: <6} ({serious_percentage: .2f}%) | Slight: {total_slight: <6} ({slight_percentage: .2f}%)")
print("="*117)  # Separator at the end
# Out:
# Severity Distribution of Incidents:
# ==================================================
# Slight     | Count: 46734  | Percentage:  87.38%
# Serious    | Count: 6340   | Percentage:  11.85%
# Fatal      | Count: 410    | Percentage:  0.77%
# ==================================================
# Total Incidents   | Count: 53484  | Fatal: 410    ( 0.77%) | Serious: 6340   ( 11.85%) | Slight: 46734  ( 87.38%)
# =====================================================================================================================

# %%
from collections import defaultdict
from datetime import datetime

# Mapping of month numbers to full month names
month_names = {
    '01': 'January', '02': 'February', '03': 'March', '04': 'April',
    '05': 'May', '06': 'June', '07': 'July', '08': 'August',
    '09': 'September', '10': 'October', '11': 'November', '12': 'December'
}

date_counter = defaultdict(int)
total_incidents = 0

# Count incidents by month
for incident in incident_data:
    date_str = incident['date']
    date_obj = datetime.fromisoformat(date_str[:-1])  # Parse date without the 'Z' at the end
    date_key = date_obj.strftime('%Y-%m')  # Group by year-month
    date_counter[date_key] += 1
    total_incidents += 1

# Find the month with the most incidents
max_month = max(date_counter, key=date_counter.get)
max_month_year, max_month_num = max_month.split('-')
max_month_name = month_names[max_month_num]
max_month_count = date_counter[max_month]

# Print header with the month with the most incidents
print("\nIncident Counts by Month:")
separator = "=" * 60  # Adjust separator width for alignment
print(separator)  # Separator

# Print the month with the most incidents at the top
print(f"Month with the Most Incidents: {max_month_name} {max_month_year} ({max_month_count:,} incidents)")

# Print the table header
print(f"\n{'Month': <15} {'Year': <10} {'Incidents': >15} {'% of Total': >15}")  # Added '% of Total' column
print("-" * 60)  # Separator between header and data

# Print incident data with aligned columns
for date, count in sorted(date_counter.items()):
    year, month = date.split('-')
    month_name = month_names[month]  # Get full month name
    percentage = (count / total_incidents) * 100 if total_incidents > 0 else 0
    print(f"{month_name: <15} {year: <10} {count: >12,} {percentage: >14.2f}%")  # Added percentage and formatted counts

print(separator)  # Separator
print(f"Total Incidents: {total_incidents:,}")  # Formatted total incidents with commas
# Out:
# Incident Counts by Month:
# ============================================================
# Month with the Most Incidents: November 2005 (4,850 incidents)
#
# Month           Year             Incidents      % of Total
# ------------------------------------------------------------
# January         2005              4,328           8.09%
# February        2005              3,862           7.22%
# March           2005              4,274           7.99%
# April           2005              4,382           8.19%
# May             2005              4,750           8.88%
# June            2005              4,682           8.75%
# July            2005              4,700           8.79%
# August          2005              4,276           7.99%
# September       2005              4,530           8.47%
# October         2005              4,714           8.81%
# November        2005              4,850           9.07%
# December        2005              4,136           7.73%
# ============================================================
# Total Incidents: 53,484

# %%
fatal_vehicle_severity_counter = {}

# Count fatal incidents by vehicle type
for incident in incident_data:
    if incident['severity'] == 'Fatal':
        for vehicle in incident['vehicles']:
            if vehicle not in fatal_vehicle_severity_counter:
                fatal_vehicle_severity_counter[vehicle] = {'fatal': 0}
            fatal_vehicle_severity_counter[vehicle]['fatal'] += 1

# Sort vehicles by the number of fatal incidents in descending order
sorted_fatal_vehicles = sorted(fatal_vehicle_severity_counter.items(), key=lambda x: x[1]['fatal'], reverse=True)

# Print fatal incidents count for each vehicle in descending order
print("\nFatal Vehicle Incidents Breakdown:")
separator = "=" * 50  # Adjust separator for neatness
print(separator)  # Separator
for vehicle, severity_counts in sorted_fatal_vehicles:
    print(f"  {vehicle: <20}: Fatal - {severity_counts['fatal']: >3}")  # Align text and numbers
print(separator)  # Separator
# Out:
# Fatal Vehicle Incidents Breakdown:
# ==================================================
#   Car                 : Fatal - 316
#   BusOrCoach          : Fatal -  50
#   Motorcycle_500cc_Plus: Fatal -  46
#   PedalCycle          : Fatal -  44
#   HeavyGoodsVehicle   : Fatal -  36
#   LightGoodsVehicle   : Fatal -  34
#   Motorcycle_125_500cc: Fatal -  26
#   Motorcycle_50_125cc : Fatal -  22
#   Taxi                : Fatal -  10
#   Motorcycle_0_50cc   : Fatal -  10
#   AgriculturalVehicle : Fatal -   2
#   MediumGoodsVehicle  : Fatal -   2
#   OtherMotorVehicle   : Fatal -   2
#   Minibus             : Fatal -   2
#   RiddenHorse         : Fatal -   2
# ==================================================

# %%
from datetime import datetime

# Extract fatal incidents
fatal_incidents = [incident for incident in incident_data if incident['severity'] == 'Fatal']

# Display fatal incidents
print(f"Total Fatal Incidents: {len(fatal_incidents)}\n")

for idx, incident in enumerate(fatal_incidents, start=1):
    # Clean up the date format
    date_str = incident['date']
    date_obj = datetime.fromisoformat(date_str[:-1])  # Parse date without the 'Z' at the end
    formatted_date = date_obj.strftime('%d %B %Y, %I:%M %p')  # Format as '17 July 2005, 05:17 AM'

    print(f"Fatal Incident {idx}:")
    print(f"  Date: {formatted_date}")
    print(f"  Borough: {incident['borough']}")
    print(f"  Location: {incident['location']}")
    print(f"  Vehicles Involved: {', '.join(incident['vehicles'])}")

    # Display all casualties (no user input)
    print("  Casualties:")
    for casualty in incident['casualties']:
        age = casualty.get('age', 'Unknown')  # Handle missing age
        print(f"    - Age: {age}, Class: {casualty['class']}, Severity: {casualty['severity']}, Mode: {casualty['mode']}, Age Band: {casualty['ageBand']}")

    print("\n" + "-" * 50 + "\n")  # Separator for readability
# Out:
# Total Fatal Incidents: 410
#
# Fatal Incident 1:
#   Date: 18 May 2005, 06:30 PM
#   Borough: City of London
#   Location: St Martin's Le Grand junction with Angel Street
#   Vehicles Involved: Motorcycle_500cc_Plus, PedalCycle
#   Casualties:
#     - Age: 20, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#     - Age: 40, Class: Driver, Severity: Slight, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 2:
#   Date: 14 July 2005, 08:15 AM
#   Borough: Camden
#   Location: St Pancras Way junction with Baynes Street
#   Vehicles Involved: HeavyGoodsVehicle, PedalCycle
#   Casualties:
#     - Age: 24, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 3:
#   Date: 13 August 2005, 12:54 AM
#   Borough: Camden
#   Location: Hampstead Road junction with Mornington Crescent
#   Vehicles Involved: Motorcycle_50_125cc
#   Casualties:
#     - Age: 28, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 4:
#   Date: 28 April 2005, 10:35 PM
#   Borough: Hillingdon
#   Location: Swan Road 50 metres south west of junction with Swans Close
#   Vehicles Involved: Car, Car, Car
#   Casualties:
#     - Age: 17, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: 17, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: 18, Class: Driver, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 17, Class: Driver, Severity: Serious, Mode: Car, Age Band: Adult
#     - Age: 16, Class: Passenger, Severity: Slight, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 5:
#   Date: 08 May 2005, 12:44 PM
#   Borough: Hillingdon
#   Location: Crowland Avenue junction with Monmouth Road
#   Vehicles Involved: Motorcycle_125_500cc, Car
#   Casualties:
#     - Age: 25, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 6:
#   Date: 30 July 2005, 01:40 AM
#   Borough: Hillingdon
#   Location: Uxbridge Road 225 metres south east of junction with The Parkway
#   Vehicles Involved: Car, BusOrCoach
#   Casualties:
#     - Age: 29, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 7:
#   Date: 08 September 2005, 12:35 AM
#   Borough: Hillingdon
#   Location: Mill Road junction with Cricketfield Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 18, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 8:
#   Date: 21 October 2005, 09:10 PM
#   Borough: Hillingdon
#   Location: Queens Walk 30 metres south of junction with Oxford Drive
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 16, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#     - Age: 14, Class: Pedestrian, Severity: Serious, Mode: Pedestrian, Age Band: Child
#
# --------------------------------------------------
#
# Fatal Incident 9:
#   Date: 07 December 2005, 06:54 PM
#   Borough: Hillingdon
#   Location: Harvil Road 490 metres south of junction with Newyears Green Lane
#   Vehicles Involved: Car, Car
#   Casualties:
#     - Age: 64, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 10:
#   Date: 15 December 2005, 08:48 AM
#   Borough: Hillingdon
#   Location: Wood Lane 30 metres east of junction with Chichester Avenue
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 79, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 11:
#   Date: 05 May 2005, 04:35 PM
#   Borough: Enfield
#   Location: Mollison Avenue junction with Green Street
#   Vehicles Involved: PedalCycle, HeavyGoodsVehicle
#   Casualties:
#     - Age: 57, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 12:
#   Date: 04 June 2005, 03:18 PM
#   Borough: Enfield
#   Location: Great Cambridge Road 70 metres north junction with Carterhatch Lane
#   Vehicles Involved: Car, HeavyGoodsVehicle
#   Casualties:
#     - Age: 53, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 13:
#   Date: 18 June 2005, 04:30 AM
#   Borough: Enfield
#   Location: Old Park Ridings junction with Park Drive
#   Vehicles Involved: Car, Motorcycle_125_500cc
#   Casualties:
#     - Age: 37, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#     - Age: 56, Class: Passenger, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 17, Class: Driver, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 33, Class: Passenger, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 14:
#   Date: 21 June 2005, 07:40 PM
#   Borough: Enfield
#   Location: Meridian Way junction with Glover Drive
#   Vehicles Involved: Motorcycle_500cc_Plus, LightGoodsVehicle
#   Casualties:
#     - Age: 36, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 15:
#   Date: 05 August 2005, 01:29 PM
#   Borough: Enfield
#   Location: Bourne Hill junction with Hedge Lane
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 85, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 16:
#   Date: 12 September 2005, 01:20 AM
#   Borough: Enfield
#   Location: North Circular Road junction with Great Cambridge Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 25, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: Unknown, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Unknown
#     - Age: Unknown, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Unknown
#
# --------------------------------------------------
#
# Fatal Incident 17:
#   Date: 13 September 2005, 04:51 PM
#   Borough: Enfield
#   Location: Winchmore Hill Road 32 metres north east junction with Crowland Gardens
#   Vehicles Involved: Car, Motorcycle_125_500cc
#   Casualties:
#     - Age: 36, Class: Passenger, Severity: Serious, Mode: PoweredTwoWheeler, Age Band: Adult
#     - Age: 45, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 18:
#   Date: 05 October 2005, 01:50 PM
#   Borough: Enfield
#   Location: Chase Side junction with Green Road
#   Vehicles Involved: BusOrCoach
#   Casualties:
#     - Age: 70, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 19:
#   Date: 23 October 2005, 01:25 AM
#   Borough: Enfield
#   Location: Fore Street junction with Park Avenue
#   Vehicles Involved: Motorcycle_50_125cc
#   Casualties:
#     - Age: 37, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 20:
#   Date: 16 November 2005, 10:20 AM
#   Borough: Enfield
#   Location: Church Street junction with Ainsley Close
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 88, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 21:
#   Date: 06 December 2005, 05:00 PM
#   Borough: Enfield
#   Location: Avenue Road junction with Highfield Court
#   Vehicles Involved: LightGoodsVehicle
#   Casualties:
#     - Age: 53, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 22:
#   Date: 14 July 2005, 08:15 AM
#   Borough: Camden
#   Location: St Pancras Way junction with Baynes Street
#   Vehicles Involved: HeavyGoodsVehicle, PedalCycle
#   Casualties:
#     - Age: 24, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 23:
#   Date: 26 April 2005, 12:40 AM
#   Borough: Tower Hamlets
#   Location: The Highway junction with King David Lane
#   Vehicles Involved: Motorcycle_500cc_Plus
#   Casualties:
#     - Age: 20, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 24:
#   Date: 25 March 2005, 10:40 PM
#   Borough: Tower Hamlets
#   Location: Bow Road 61 metres west junction with Fairfield Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 24, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 25:
#   Date: 12 June 2005, 06:24 PM
#   Borough: Tower Hamlets
#   Location: Bethnal Green Road junction with Rushmead
#   Vehicles Involved: Motorcycle_125_500cc
#   Casualties:
#     - Age: 41, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 26:
#   Date: 02 September 2005, 07:35 AM
#   Borough: Tower Hamlets
#   Location: East India Dock Road junction with Cotton Street
#   Vehicles Involved: AgriculturalVehicle, Motorcycle_500cc_Plus
#   Casualties:
#     - Age: 44, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 27:
#   Date: 17 September 2005, 01:40 PM
#   Borough: Tower Hamlets
#   Location: Grove Road junction with Ashcroft Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 56, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 28:
#   Date: 06 October 2005, 09:06 PM
#   Borough: Tower Hamlets
#   Location: Roman Road junction with Globe Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 18, Class: Passenger, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 19, Class: Driver, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 30, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 29:
#   Date: 04 November 2005, 05:59 PM
#   Borough: Tower Hamlets
#   Location: Vallance Road junction with Whitechapel Road
#   Vehicles Involved: Motorcycle_125_500cc
#   Casualties:
#     - Age: 32, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#     - Age: 21, Class: Driver, Severity: Serious, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 30:
#   Date: 26 July 2005, 11:45 PM
#   Borough: Newham
#   Location: Bidder Street junction with Wharfside Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 20, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 31:
#   Date: 10 September 2005, 07:20 AM
#   Borough: Newham
#   Location: Portway 38 metres west junction with Park Road
#   Vehicles Involved: LightGoodsVehicle, Car
#   Casualties:
#     - Age: 32, Class: Passenger, Severity: Slight, Mode: GoodsVehicle, Age Band: Adult
#     - Age: 27, Class: Driver, Severity: Slight, Mode: GoodsVehicle, Age Band: Adult
#     - Age: 39, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 32:
#   Date: 20 February 2005, 03:10 PM
#   Borough: Tower Hamlets
#   Location: Mile End Road junction with Assembly Passage
#   Vehicles Involved: PedalCycle
#   Casualties:
#     - Age: 26, Class: Driver, Severity: Slight, Mode: PedalCycle, Age Band: Adult
#     - Age: 42, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 33:
#   Date: 26 April 2005, 12:40 AM
#   Borough: Tower Hamlets
#   Location: The Highway junction with King David Lane
#   Vehicles Involved: Motorcycle_500cc_Plus
#   Casualties:
#     - Age: 20, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 34:
#   Date: 25 March 2005, 10:40 PM
#   Borough: Tower Hamlets
#   Location: Bow Road 61 metres west junction with Fairfield Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 24, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 35:
#   Date: 12 June 2005, 06:24 PM
#   Borough: Tower Hamlets
#   Location: Bethnal Green Road junction with Rushmead
#   Vehicles Involved: Motorcycle_125_500cc
#   Casualties:
#     - Age: 41, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 36:
#   Date: 02 September 2005, 07:35 AM
#   Borough: Tower Hamlets
#   Location: East India Dock Road junction with Cotton Street
#   Vehicles Involved: AgriculturalVehicle, Motorcycle_500cc_Plus
#   Casualties:
#     - Age: 44, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 37:
#   Date: 17 September 2005, 01:40 PM
#   Borough: Tower Hamlets
#   Location: Grove Road junction with Ashcroft Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 56, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 38:
#   Date: 06 October 2005, 09:06 PM
#   Borough: Tower Hamlets
#   Location: Roman Road junction with Globe Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 18, Class: Passenger, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 19, Class: Driver, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 30, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 39:
#   Date: 01 April 2005, 08:08 PM
#   Borough: Southwark
#   Location: Jamaica Road junction with Abbey Street
#   Vehicles Involved: Motorcycle_500cc_Plus
#   Casualties:
#     - Age: 14, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Child
#
# --------------------------------------------------
#
# Fatal Incident 40:
#   Date: 29 June 2005, 05:35 PM
#   Borough: Southwark
#   Location: Ann Moss Way junction with Lower Road
#   Vehicles Involved: Car, Motorcycle_125_500cc
#   Casualties:
#     - Age: 52, Class: Driver, Severity: Serious, Mode: Car, Age Band: Adult
#     - Age: 36, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 41:
#   Date: 18 May 2005, 06:30 PM
#   Borough: City of London
#   Location: St Martin's Le Grand junction with Angel Street
#   Vehicles Involved: Motorcycle_500cc_Plus, PedalCycle
#   Casualties:
#     - Age: 20, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#     - Age: 40, Class: Driver, Severity: Slight, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 42:
#   Date: 17 July 2005, 05:17 AM
#   Borough: Southwark
#   Location: Lordship Lane 40 metres south of junction with Overhill Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 30, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: 64, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: 23, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: Unknown, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Unknown
#
# --------------------------------------------------
#
# Fatal Incident 43:
#   Date: 20 July 2005, 10:08 PM
#   Borough: Southwark
#   Location: Long Lane junction with Kipling Street
#   Vehicles Involved: Taxi
#   Casualties:
#     - Age: 63, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 44:
#   Date: 25 October 2005, 07:35 PM
#   Borough: Southwark
#   Location: Westmoreland Road junction with Queen's Row
#   Vehicles Involved: Motorcycle_50_125cc, Car
#   Casualties:
#     - Age: 19, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 45:
#   Date: 04 November 2005, 05:59 PM
#   Borough: Tower Hamlets
#   Location: Vallance Road junction with Whitechapel Road
#   Vehicles Involved: Motorcycle_125_500cc
#   Casualties:
#     - Age: 32, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#     - Age: 21, Class: Driver, Severity: Serious, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 46:
#   Date: 26 October 2005, 10:29 AM
#   Borough: Brent
#   Location: Netherwood Street junction with Kilburn High Road
#   Vehicles Involved: LightGoodsVehicle
#   Casualties:
#     - Age: 68, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 47:
#   Date: 13 January 2005, 10:10 PM
#   Borough: Brent
#   Location: Harrow Road junction with Felixstowe Road
#   Vehicles Involved: Car, Car
#   Casualties:
#     - Age: 25, Class: Passenger, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: Unknown, Class: Driver, Severity: Slight, Mode: Car, Age Band: Unknown
#     - Age: Unknown, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Unknown
#     - Age: 33, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 48:
#   Date: 01 April 2005, 08:08 PM
#   Borough: Southwark
#   Location: Jamaica Road junction with Abbey Street
#   Vehicles Involved: Motorcycle_500cc_Plus
#   Casualties:
#     - Age: 14, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Child
#
# --------------------------------------------------
#
# Fatal Incident 49:
#   Date: 29 June 2005, 05:35 PM
#   Borough: Southwark
#   Location: Ann Moss Way junction with Lower Road
#   Vehicles Involved: Car, Motorcycle_125_500cc
#   Casualties:
#     - Age: 52, Class: Driver, Severity: Serious, Mode: Car, Age Band: Adult
#     - Age: 36, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 50:
#   Date: 17 July 2005, 05:17 AM
#   Borough: Southwark
#   Location: Lordship Lane 40 metres south of junction with Overhill Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 30, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: 64, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: 23, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: Unknown, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Unknown
#
# --------------------------------------------------
#
# Fatal Incident 51:
#   Date: 20 July 2005, 10:08 PM
#   Borough: Southwark
#   Location: Long Lane junction with Kipling Street
#   Vehicles Involved: Taxi
#   Casualties:
#     - Age: 63, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 52:
#   Date: 25 October 2005, 07:35 PM
#   Borough: Southwark
#   Location: Westmoreland Road junction with Queen's Row
#   Vehicles Involved: Motorcycle_50_125cc, Car
#   Casualties:
#     - Age: 19, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 53:
#   Date: 31 July 2005, 02:00 AM
#   Borough: Merton
#   Location: Worple Road junction with Pepys Road
#   Vehicles Involved: Car, Car
#   Casualties:
#     - Age: 52, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Adult
#     - Age: 25, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Adult
#     - Age: 30, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 54:
#   Date: 15 May 2005, 08:37 PM
#   Borough: Brent
#   Location: Longley Avenue 130 metres north junction with Queensbury Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 2, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Child
#
# --------------------------------------------------
#
# Fatal Incident 55:
#   Date: 29 May 2005, 12:05 AM
#   Borough: Brent
#   Location: Bridge Road 80 metres north east junction with Brook Avenue
#   Vehicles Involved: BusOrCoach
#   Casualties:
#     - Age: 36, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 56:
#   Date: 27 October 2005, 07:46 PM
#   Borough: Brent
#   Location: Hillside 40 metres west of junction with Brentfield Road
#   Vehicles Involved: LightGoodsVehicle
#   Casualties:
#     - Age: 51, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 57:
#   Date: 26 November 2005, 01:30 AM
#   Borough: Brent
#   Location: Ealing Road junction with Glacier Way
#   Vehicles Involved: Car, Car
#   Casualties:
#     - Age: 33, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 58:
#   Date: 12 November 2005, 12:00 PM
#   Borough: Brent
#   Location: Forty Lane junction with Kings Drive
#   Vehicles Involved: BusOrCoach
#   Casualties:
#     - Age: 84, Class: Passenger, Severity: Fatal, Mode: BusOrCoach, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 59:
#   Date: 04 March 2005, 01:45 PM
#   Borough: Redbridge
#   Location: High Street junction with Freemantle Road
#   Vehicles Involved: HeavyGoodsVehicle
#   Casualties:
#     - Age: 82, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 60:
#   Date: 17 March 2005, 02:35 PM
#   Borough: Redbridge
#   Location: Romford Road 148 metres south east junction with Latchford Place
#   Vehicles Involved: Car, Motorcycle_500cc_Plus
#   Casualties:
#     - Age: 85, Class: Passenger, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 21, Class: Driver, Severity: Serious, Mode: PoweredTwoWheeler, Age Band: Adult
#     - Age: 84, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 61:
#   Date: 18 June 2005, 04:58 PM
#   Borough: Redbridge
#   Location: Clayhall Avenue 64 metres north east junction with Woodford Avenue
#   Vehicles Involved: HeavyGoodsVehicle, Motorcycle_125_500cc
#   Casualties:
#     - Age: 76, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 62:
#   Date: 21 July 2005, 05:28 PM
#   Borough: Redbridge
#   Location: Southend Road 200 metres east offslip M11
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 13, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Child
#
# --------------------------------------------------
#
# Fatal Incident 63:
#   Date: 23 August 2005, 06:10 PM
#   Borough: Redbridge
#   Location: Eastern Avenue junction with Hainault Road
#   Vehicles Involved: Motorcycle_500cc_Plus
#   Casualties:
#     - Age: 55, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 64:
#   Date: 16 September 2005, 04:10 PM
#   Borough: Redbridge
#   Location: Clarence Avenue 40 metres north east junction with The Crescent
#   Vehicles Involved: BusOrCoach
#   Casualties:
#     - Age: 85, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 65:
#   Date: 09 November 2005, 09:20 AM
#   Borough: Bexley
#   Location: Westwood Lane J/E Bellegrove Road
#   Vehicles Involved: BusOrCoach
#   Casualties:
#     - Age: 79, Class: Passenger, Severity: Fatal, Mode: BusOrCoach, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 66:
#   Date: 16 February 2005, 11:12 PM
#   Borough: Hammersmith and Fulham
#   Location: Sawley Road junction with Wormholt Road
#   Vehicles Involved: Car, Car
#   Casualties:
#     - Age: 51, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: Unknown, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Unknown
#     - Age: 26, Class: Passenger, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 26, Class: Passenger, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 12, Class: Passenger, Severity: Slight, Mode: Car, Age Band: Child
#     - Age: Unknown, Class: Passenger, Severity: Slight, Mode: Car, Age Band: Unknown
#     - Age: Unknown, Class: Passenger, Severity: Slight, Mode: Car, Age Band: Unknown
#     - Age: 26, Class: Driver, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 23, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 67:
#   Date: 01 June 2005, 06:59 PM
#   Borough: Hammersmith and Fulham
#   Location: Wandsworth Bridge Road 29 metres south of junction with Ryecroft Street
#   Vehicles Involved: Motorcycle_500cc_Plus, Car
#   Casualties:
#     - Age: 27, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 68:
#   Date: 30 June 2005, 05:05 PM
#   Borough: Hammersmith and Fulham
#   Location: Ravenscourt Park 51 metres south junction with Ravenscourt Gardens
#   Vehicles Involved: Motorcycle_500cc_Plus
#   Casualties:
#     - Age: 29, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 69:
#   Date: 30 August 2005, 12:52 PM
#   Borough: Hammersmith and Fulham
#   Location: Loftus Road 33 metres south junction with Ellerslie Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 7, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Child
#
# --------------------------------------------------
#
# Fatal Incident 70:
#   Date: 30 September 2005, 02:05 AM
#   Borough: Hammersmith and Fulham
#   Location: Goldhawk Road junction with Richford Street
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 35, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 71:
#   Date: 12 November 2005, 09:28 AM
#   Borough: Redbridge
#   Location: Goodmayes Lane 23 metres south junction with Cardigan Gardens
#   Vehicles Involved: Car, PedalCycle
#   Casualties:
#     - Age: 89, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 72:
#   Date: 15 March 2005, 09:10 PM
#   Borough: Bexley
#   Location: Hatherley Road junction with Gresswell Close
#   Vehicles Involved: Car, LightGoodsVehicle
#   Casualties:
#     - Age: 22, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 73:
#   Date: 23 October 2005, 12:09 AM
#   Borough: Hammersmith and Fulham
#   Location: Westway junction with west Cross Route
#   Vehicles Involved: Car, Car, Car, Car
#   Casualties:
#     - Age: 30, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Adult
#     - Age: 41, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Adult
#     - Age: 45, Class: Driver, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 52, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Adult
#     - Age: 58, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: 3, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Child
#
# --------------------------------------------------
#
# Fatal Incident 74:
#   Date: 08 November 2005, 08:18 PM
#   Borough: Hammersmith and Fulham
#   Location: Fulham Palace Road junction with Averill Street
#   Vehicles Involved: Motorcycle_50_125cc
#   Casualties:
#     - Age: 28, Class: Pedestrian, Severity: Serious, Mode: Pedestrian, Age Band: Adult
#     - Age: 20, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 75:
#   Date: 20 November 2005, 09:10 PM
#   Borough: Hammersmith and Fulham
#   Location: Wood Lane 144 metres south junction with south Africa Road
#   Vehicles Involved: Motorcycle_50_125cc
#   Casualties:
#     - Age: 38, Class: Driver, Severity: Slight, Mode: PoweredTwoWheeler, Age Band: Adult
#     - Age: 57, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 76:
#   Date: 09 December 2005, 03:35 PM
#   Borough: Hammersmith and Fulham
#   Location: Fulham Road junction with Waldemar Avenue
#   Vehicles Involved: BusOrCoach, Motorcycle_0_50cc
#   Casualties:
#     - Age: 25, Class: Driver, Severity: Slight, Mode: BusOrCoach, Age Band: Adult
#     - Age: 19, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 77:
#   Date: 14 December 2005, 08:29 AM
#   Borough: Hammersmith and Fulham
#   Location: Shepherd's Bush Road junction with Shepherd's Bush Green
#   Vehicles Involved: Motorcycle_50_125cc, HeavyGoodsVehicle
#   Casualties:
#     - Age: 43, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 78:
#   Date: 08 October 2005, 10:05 PM
#   Borough: Bexley
#   Location: Station Road 50 metres south of junction with Sandhurst Road
#   Vehicles Involved: Car, Car
#   Casualties:
#     - Age: 30, Class: Driver, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 24, Class: Passenger, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 29, Class: Driver, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 67, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 79:
#   Date: 24 November 2005, 07:50 AM
#   Borough: Bexley
#   Location: King Harold's Way junction with Bedonwell Road
#   Vehicles Involved: LightGoodsVehicle
#   Casualties:
#     - Age: 48, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 80:
#   Date: 17 December 2005, 12:36 AM
#   Borough: Bexley
#   Location: Main Road 34 metres east of junction with Marechal Niel Avenue
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 40, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 81:
#   Date: 23 December 2005, 11:30 PM
#   Borough: Bexley
#   Location: Manor Road junction with Bilton Road
#   Vehicles Involved: Car, Car
#   Casualties:
#     - Age: 37, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 82:
#   Date: 27 April 2005, 10:09 AM
#   Borough: Islington
#   Location: Drayton Park junction with Arvon Road
#   Vehicles Involved: HeavyGoodsVehicle, PedalCycle
#   Casualties:
#     - Age: 34, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 83:
#   Date: 27 March 2005, 05:40 AM
#   Borough: Kingston
#   Location: Malden Way 50 metres west junction with Malden Road
#   Vehicles Involved: Motorcycle_50_125cc
#   Casualties:
#     - Age: 51, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 84:
#   Date: 29 March 2005, 08:00 PM
#   Borough: Kingston
#   Location: Ewell Road junction with Worthington Road
#   Vehicles Involved: Car, Car
#   Casualties:
#     - Age: 85, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 85:
#   Date: 18 July 2005, 01:16 PM
#   Borough: Kingston
#   Location: Portsmouth Road junction with Grove Road
#   Vehicles Involved: Car, Car
#   Casualties:
#     - Age: 87, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: 73, Class: Driver, Severity: Serious, Mode: Car, Age Band: Adult
#     - Age: 17, Class: Passenger, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 19, Class: Driver, Severity: Serious, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 86:
#   Date: 28 February 2005, 02:14 AM
#   Borough: Ealing
#   Location: Western Avenue 275 metres east of junction with B456
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 20, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: 21, Class: Passenger, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 20, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 87:
#   Date: 02 May 2005, 05:07 AM
#   Borough: Ealing
#   Location: Western Avenue 144 metres east junction with Alperton Lane
#   Vehicles Involved: Car, Car
#   Casualties:
#     - Age: 22, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 88:
#   Date: 26 May 2005, 11:55 PM
#   Borough: Ealing
#   Location: Western Avenue 154 metres north west junction with Church Road
#   Vehicles Involved: Car, HeavyGoodsVehicle
#   Casualties:
#     - Age: 56, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 89:
#   Date: 03 July 2005, 03:30 PM
#   Borough: Ealing
#   Location: Lady Margaret Road 35 metres south of junction with Ascot Gardens
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 77, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 90:
#   Date: 17 October 2005, 06:57 PM
#   Borough: Ealing
#   Location: Western Avenue junction with Old Oak Common Lane
#   Vehicles Involved: BusOrCoach
#   Casualties:
#     - Age: 50, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 91:
#   Date: 08 December 2005, 05:28 PM
#   Borough: Ealing
#   Location: Ruislip Road east 68 metres west of junction with Gurnell Grove
#   Vehicles Involved: BusOrCoach
#   Casualties:
#     - Age: 10, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Child
#
# --------------------------------------------------
#
# Fatal Incident 92:
#   Date: 14 December 2005, 04:30 AM
#   Borough: Ealing
#   Location: Gunnersbury Avenue 50 metres south of junction with Crosslands Avenue
#   Vehicles Involved: Car, BusOrCoach
#   Casualties:
#     - Age: 39, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: 35, Class: Driver, Severity: Serious, Mode: BusOrCoach, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 93:
#   Date: 31 July 2005, 07:20 AM
#   Borough: Ealing
#   Location: The Vale 40 metres west junction with Askew Road
#   Vehicles Involved: Car, Taxi
#   Casualties:
#     - Age: 39, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: 71, Class: Driver, Severity: Slight, Mode: Taxi, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 94:
#   Date: 22 June 2005, 11:45 AM
#   Borough: Richmond upon Thames
#   Location: Staines Road junction with Court Close Avenue
#   Vehicles Involved: Car, PedalCycle
#   Casualties:
#     - Age: 25, Class: Driver, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 83, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 95:
#   Date: 16 November 2005, 09:30 PM
#   Borough: Richmond upon Thames
#   Location: Hounslow Road 57 metres north west of junction with Vicarage Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 21, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 96:
#   Date: 14 May 2005, 06:40 AM
#   Borough: Harrow
#   Location: Courtenay Avenue 68 metres south junction with Secker Crescent
#   Vehicles Involved: Motorcycle_500cc_Plus
#   Casualties:
#     - Age: 40, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 97:
#   Date: 13 June 2005, 05:11 PM
#   Borough: Harrow
#   Location: Marsh Lane 20 metres north of junction with Du Cros Drive
#   Vehicles Involved: HeavyGoodsVehicle, Car
#   Casualties:
#     - Age: 55, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 98:
#   Date: 16 September 2005, 01:30 AM
#   Borough: Harrow
#   Location: Old Redding 295Mwest junction with Brookshill
#   Vehicles Involved: PedalCycle
#   Casualties:
#     - Age: 54, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 99:
#   Date: 30 September 2005, 02:04 PM
#   Borough: Islington
#   Location: Highbury Grove junction with Highbury New Park
#   Vehicles Involved: BusOrCoach
#   Casualties:
#     - Age: 15, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Child
#
# --------------------------------------------------
#
# Fatal Incident 100:
#   Date: 15 November 2005, 09:15 AM
#   Borough: Islington
#   Location: Hornsey Rise junction with Cromartie Road
#   Vehicles Involved: PedalCycle, LightGoodsVehicle
#   Casualties:
#     - Age: 30, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 101:
#   Date: 18 November 2005, 07:27 AM
#   Borough: Islington
#   Location: Clerkenwell Road junction with St John Street
#   Vehicles Involved: PedalCycle, HeavyGoodsVehicle
#   Casualties:
#     - Age: 37, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 102:
#   Date: 06 January 2005, 03:32 PM
#   Borough: City of Westminster
#   Location: Maida Vale junction with Clifton Road
#   Vehicles Involved: PedalCycle, Car
#   Casualties:
#     - Age: 25, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 103:
#   Date: 02 February 2005, 09:00 AM
#   Borough: City of Westminster
#   Location: Hyde Park Gdns junction with Brook Street
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 42, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 104:
#   Date: 29 January 2005, 12:00 PM
#   Borough: City of Westminster
#   Location: Exeter Street junction with Wellington Street
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 25, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 105:
#   Date: 24 March 2005, 10:29 PM
#   Borough: City of Westminster
#   Location: Piccadily junction with Brick Street
#   Vehicles Involved: Taxi, PedalCycle
#   Casualties:
#     - Age: 20, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 106:
#   Date: 01 April 2005, 04:07 PM
#   Borough: City of Westminster
#   Location: Grosvenor Place 37 metres south east of junction with Halkin Street
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 24, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 107:
#   Date: 08 May 2005, 06:00 AM
#   Borough: City of Westminster
#   Location: Hanover Square 22 metres north junction with Brook Street
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 21, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 108:
#   Date: 25 February 2005, 09:39 PM
#   Borough: Havering
#   Location: Rush Green Road 81 metres east of junction with Leonard Avenue
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 27, Class: Driver, Severity: Serious, Mode: Car, Age Band: Adult
#     - Age: 26, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: Unknown, Class: Passenger, Severity: Slight, Mode: Car, Age Band: Unknown
#     - Age: 24, Class: Passenger, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 21, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: 33, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 109:
#   Date: 28 May 2005, 11:30 AM
#   Borough: Havering
#   Location: New Road junction with Sandy Lane
#   Vehicles Involved: Car, HeavyGoodsVehicle
#   Casualties:
#     - Age: 74, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: 68, Class: Driver, Severity: Serious, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 110:
#   Date: 03 July 2005, 07:05 PM
#   Borough: Havering
#   Location: Eastern Avenue east 270 metres west junction with Masefield Crescent
#   Vehicles Involved: Motorcycle_500cc_Plus
#   Casualties:
#     - Age: 47, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 111:
#   Date: 20 November 2005, 08:00 PM
#   Borough: Havering
#   Location: A13 junction with New Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 18, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: 24, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Adult
#     - Age: 19, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Adult
#     - Age: 18, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 112:
#   Date: 24 November 2005, 05:05 PM
#   Borough: Havering
#   Location: Suttons Lane 30 metres north junction with Standen Avenue
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 83, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 113:
#   Date: 18 December 2005, 10:22 AM
#   Borough: Havering
#   Location: Collier Row Lane 50 metres north of junction with Lowshoe Lane
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 78, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 114:
#   Date: 06 November 2005, 02:30 AM
#   Borough: City of Westminster
#   Location: Piccadilly Underpass 34 metres west junction with Duke of Wellington Place
#   Vehicles Involved: Car, Car, Car
#   Casualties:
#     - Age: 41, Class: Driver, Severity: Serious, Mode: Car, Age Band: Adult
#     - Age: Unknown, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Unknown
#     - Age: Unknown, Class: Driver, Severity: Serious, Mode: Car, Age Band: Unknown
#     - Age: Unknown, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Unknown
#     - Age: Unknown, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Unknown
#     - Age: Unknown, Class: Driver, Severity: Serious, Mode: Car, Age Band: Unknown
#     - Age: Unknown, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Unknown
#     - Age: 21, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: Unknown, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Unknown
#     - Age: Unknown, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Unknown
#
# --------------------------------------------------
#
# Fatal Incident 115:
#   Date: 30 October 2005, 09:38 AM
#   Borough: City of Westminster
#   Location: Edgware Road junction with Marble Arch
#   Vehicles Involved: Car, BusOrCoach
#   Casualties:
#     - Age: 31, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#     - Age: 63, Class: Driver, Severity: Serious, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 116:
#   Date: 30 November 2005, 12:30 PM
#   Borough: City of Westminster
#   Location: Penfold Street junction with Luton Street
#   Vehicles Involved: LightGoodsVehicle
#   Casualties:
#     - Age: 85, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 117:
#   Date: 26 December 2005, 12:18 AM
#   Borough: City of Westminster
#   Location: Harrow Road junction with Porchester Road
#   Vehicles Involved: Motorcycle_500cc_Plus
#   Casualties:
#     - Age: 28, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#     - Age: 20, Class: Passenger, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 118:
#   Date: 29 November 2005, 08:31 AM
#   Borough: City of Westminster
#   Location: Shirland Road junction with Essendine Road
#   Vehicles Involved: Motorcycle_500cc_Plus
#   Casualties:
#     - Age: 26, Class: Driver, Severity: Slight, Mode: PoweredTwoWheeler, Age Band: Adult
#     - Age: 52, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 119:
#   Date: 15 June 2005, 04:45 PM
#   Borough: Lambeth
#   Location: Wandsworth Road 67 metres south junction with Miles Street
#   Vehicles Involved: BusOrCoach
#   Casualties:
#     - Age: 40, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 120:
#   Date: 20 April 2005, 05:10 PM
#   Borough: Lambeth
#   Location: Atkins Road junction with New Park Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 35, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 121:
#   Date: 23 June 2005, 07:20 AM
#   Borough: Lambeth
#   Location: Streatham High Road 25 metres north of junction with Woodbourne Avenue
#   Vehicles Involved: LightGoodsVehicle, PedalCycle
#   Casualties:
#     - Age: 55, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 122:
#   Date: 11 August 2005, 10:19 AM
#   Borough: Lambeth
#   Location: Norwood Road junction with Tulse Hill
#   Vehicles Involved: BusOrCoach
#   Casualties:
#     - Age: 71, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 123:
#   Date: 07 October 2005, 06:05 PM
#   Borough: Lambeth
#   Location: South Lambeth Road junction with Kennington Lane
#   Vehicles Involved: Taxi
#   Casualties:
#     - Age: 77, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 124:
#   Date: 14 November 2005, 09:22 PM
#   Borough: Lambeth
#   Location: Milkwood Road 22 metres north junction with Shardcroft Avenue
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 45, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 125:
#   Date: 15 December 2005, 08:25 AM
#   Borough: Lambeth
#   Location: Clapham Road junction with Fentiman Road
#   Vehicles Involved: HeavyGoodsVehicle, PedalCycle
#   Casualties:
#     - Age: 34, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 126:
#   Date: 21 December 2005, 05:19 AM
#   Borough: Lambeth
#   Location: Kings Avenue 40 metres south of junction with Headlam Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 21, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 127:
#   Date: 16 February 2005, 11:12 PM
#   Borough: Hammersmith and Fulham
#   Location: Sawley Road junction with Wormholt Road
#   Vehicles Involved: Car, Car
#   Casualties:
#     - Age: 51, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: Unknown, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Unknown
# ...
#
# --------------------------------------------------
#
# Fatal Incident 368:
#   Date: 12 March 2005, 02:20 AM
#   Borough: Lewisham
#   Location: Lawrie Park Road 22 metres south junction with Colvin Close
#   Vehicles Involved: Car, Car
#   Casualties:
#     - Age: 17, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Adult
#     - Age: 22, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Adult
#     - Age: 16, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 369:
#   Date: 10 August 2005, 05:33 PM
#   Borough: Lewisham
#   Location: Lewisham Way 40 metres south east of junction with Parkfield Road
#   Vehicles Involved: Motorcycle_500cc_Plus
#   Casualties:
#     - Age: 24, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 370:
#   Date: 15 October 2005, 12:01 AM
#   Borough: Lewisham
#   Location: Bromley Road junction with Oakbridge Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: Unknown, Class: Pedestrian, Severity: Serious, Mode: Pedestrian, Age Band: Unknown
#     - Age: 45, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 371:
#   Date: 29 November 2005, 08:58 AM
#   Borough: Lewisham
#   Location: Verdant Lane 30 metres south of junction with Pasture Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 88, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 372:
#   Date: 14 December 2005, 09:15 PM
#   Borough: Lewisham
#   Location: Verdant Lane junction with Hazelbank Road
#   Vehicles Involved: Car, LightGoodsVehicle
#   Casualties:
#     - Age: 40, Class: Driver, Severity: Serious, Mode: GoodsVehicle, Age Band: Adult
#     - Age: 75, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: 37, Class: Passenger, Severity: Slight, Mode: GoodsVehicle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 373:
#   Date: 26 October 2005, 10:29 AM
#   Borough: Brent
#   Location: Netherwood Street junction with Kilburn High Road
#   Vehicles Involved: LightGoodsVehicle
#   Casualties:
#     - Age: 68, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 374:
#   Date: 13 January 2005, 10:10 PM
#   Borough: Brent
#   Location: Harrow Road junction with Felixstowe Road
#   Vehicles Involved: Car, Car
#   Casualties:
#     - Age: 25, Class: Passenger, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: Unknown, Class: Driver, Severity: Slight, Mode: Car, Age Band: Unknown
#     - Age: Unknown, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Unknown
#     - Age: 33, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 375:
#   Date: 15 May 2005, 08:37 PM
#   Borough: Brent
#   Location: Longley Avenue 130 metres north junction with Queensbury Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 2, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Child
#
# --------------------------------------------------
#
# Fatal Incident 376:
#   Date: 29 May 2005, 12:05 AM
#   Borough: Brent
#   Location: Bridge Road 80 metres north east junction with Brook Avenue
#   Vehicles Involved: BusOrCoach
#   Casualties:
#     - Age: 36, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 377:
#   Date: 27 October 2005, 07:46 PM
#   Borough: Brent
#   Location: Hillside 40 metres west of junction with Brentfield Road
#   Vehicles Involved: LightGoodsVehicle
#   Casualties:
#     - Age: 51, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 378:
#   Date: 26 November 2005, 01:30 AM
#   Borough: Brent
#   Location: Ealing Road junction with Glacier Way
#   Vehicles Involved: Car, Car
#   Casualties:
#     - Age: 33, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 379:
#   Date: 12 November 2005, 12:00 PM
#   Borough: Brent
#   Location: Forty Lane junction with Kings Drive
#   Vehicles Involved: BusOrCoach
#   Casualties:
#     - Age: 84, Class: Passenger, Severity: Fatal, Mode: BusOrCoach, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 380:
#   Date: 28 April 2005, 10:35 PM
#   Borough: Hillingdon
#   Location: Swan Road 50 metres south west of junction with Swans Close
#   Vehicles Involved: Car, Car, Car
#   Casualties:
#     - Age: 17, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: 17, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: 18, Class: Driver, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 17, Class: Driver, Severity: Serious, Mode: Car, Age Band: Adult
#     - Age: 16, Class: Passenger, Severity: Slight, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 381:
#   Date: 08 May 2005, 12:44 PM
#   Borough: Hillingdon
#   Location: Crowland Avenue junction with Monmouth Road
#   Vehicles Involved: Motorcycle_125_500cc, Car
#   Casualties:
#     - Age: 25, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 382:
#   Date: 30 July 2005, 01:40 AM
#   Borough: Hillingdon
#   Location: Uxbridge Road 225 metres south east of junction with The Parkway
#   Vehicles Involved: Car, BusOrCoach
#   Casualties:
#     - Age: 29, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 383:
#   Date: 08 September 2005, 12:35 AM
#   Borough: Hillingdon
#   Location: Mill Road junction with Cricketfield Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 18, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 384:
#   Date: 21 October 2005, 09:10 PM
#   Borough: Hillingdon
#   Location: Queens Walk 30 metres south of junction with Oxford Drive
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 16, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#     - Age: 14, Class: Pedestrian, Severity: Serious, Mode: Pedestrian, Age Band: Child
#
# --------------------------------------------------
#
# Fatal Incident 385:
#   Date: 07 December 2005, 06:54 PM
#   Borough: Hillingdon
#   Location: Harvil Road 490 metres south of junction with Newyears Green Lane
#   Vehicles Involved: Car, Car
#   Casualties:
#     - Age: 64, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 386:
#   Date: 15 December 2005, 08:48 AM
#   Borough: Hillingdon
#   Location: Wood Lane 30 metres east of junction with Chichester Avenue
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 79, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 387:
#   Date: 13 January 2005, 10:31 PM
#   Borough: Enfield
#   Location: Mollison Avenue 75 metres south of junction with Ordnance Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 19, Class: Driver, Severity: Serious, Mode: Car, Age Band: Adult
#     - Age: 19, Class: Passenger, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: 17, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 388:
#   Date: 05 May 2005, 04:35 PM
#   Borough: Enfield
#   Location: Mollison Avenue junction with Green Street
#   Vehicles Involved: PedalCycle, HeavyGoodsVehicle
#   Casualties:
#     - Age: 57, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 389:
#   Date: 04 June 2005, 03:18 PM
#   Borough: Enfield
#   Location: Great Cambridge Road 70 metres north junction with Carterhatch Lane
#   Vehicles Involved: Car, HeavyGoodsVehicle
#   Casualties:
#     - Age: 53, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 390:
#   Date: 18 June 2005, 04:30 AM
#   Borough: Enfield
#   Location: Old Park Ridings junction with Park Drive
#   Vehicles Involved: Car, Motorcycle_125_500cc
#   Casualties:
#     - Age: 37, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#     - Age: 56, Class: Passenger, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 17, Class: Driver, Severity: Slight, Mode: Car, Age Band: Adult
#     - Age: 33, Class: Passenger, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 391:
#   Date: 21 June 2005, 07:40 PM
#   Borough: Enfield
#   Location: Meridian Way junction with Glover Drive
#   Vehicles Involved: Motorcycle_500cc_Plus, LightGoodsVehicle
#   Casualties:
#     - Age: 36, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 392:
#   Date: 05 August 2005, 01:29 PM
#   Borough: Enfield
#   Location: Bourne Hill junction with Hedge Lane
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 85, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 393:
#   Date: 12 September 2005, 01:20 AM
#   Borough: Enfield
#   Location: North Circular Road junction with Great Cambridge Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 25, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#     - Age: Unknown, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Unknown
#     - Age: Unknown, Class: Passenger, Severity: Serious, Mode: Car, Age Band: Unknown
#
# --------------------------------------------------
#
# Fatal Incident 394:
#   Date: 13 September 2005, 04:51 PM
#   Borough: Enfield
#   Location: Winchmore Hill Road 32 metres north east junction with Crowland Gardens
#   Vehicles Involved: Car, Motorcycle_125_500cc
#   Casualties:
#     - Age: 36, Class: Passenger, Severity: Serious, Mode: PoweredTwoWheeler, Age Band: Adult
#     - Age: 45, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 395:
#   Date: 05 October 2005, 01:50 PM
#   Borough: Enfield
#   Location: Chase Side junction with Green Road
#   Vehicles Involved: BusOrCoach
#   Casualties:
#     - Age: 70, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 396:
#   Date: 23 October 2005, 01:25 AM
#   Borough: Enfield
#   Location: Fore Street junction with Park Avenue
#   Vehicles Involved: Motorcycle_50_125cc
#   Casualties:
#     - Age: 37, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 397:
#   Date: 16 November 2005, 10:20 AM
#   Borough: Enfield
#   Location: Church Street junction with Ainsley Close
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 88, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 398:
#   Date: 06 December 2005, 05:00 PM
#   Borough: Enfield
#   Location: Avenue Road junction with Highfield Court
#   Vehicles Involved: LightGoodsVehicle
#   Casualties:
#     - Age: 53, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 399:
#   Date: 26 July 2005, 11:45 PM
#   Borough: Newham
#   Location: Bidder Street junction with Wharfside Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 20, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 400:
#   Date: 10 September 2005, 07:20 AM
#   Borough: Newham
#   Location: Portway 38 metres west junction with Park Road
#   Vehicles Involved: LightGoodsVehicle, Car
#   Casualties:
#     - Age: 32, Class: Passenger, Severity: Slight, Mode: GoodsVehicle, Age Band: Adult
#     - Age: 27, Class: Driver, Severity: Slight, Mode: GoodsVehicle, Age Band: Adult
#     - Age: 39, Class: Driver, Severity: Fatal, Mode: Car, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 401:
#   Date: 13 August 2005, 12:54 AM
#   Borough: Camden
#   Location: Hampstead Road junction with Mornington Crescent
#   Vehicles Involved: Motorcycle_50_125cc
#   Casualties:
#     - Age: 28, Class: Driver, Severity: Fatal, Mode: PoweredTwoWheeler, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 402:
#   Date: 27 April 2005, 10:09 AM
#   Borough: Islington
#   Location: Drayton Park junction with Arvon Road
#   Vehicles Involved: HeavyGoodsVehicle, PedalCycle
#   Casualties:
#     - Age: 34, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 403:
#   Date: 30 September 2005, 02:04 PM
#   Borough: Islington
#   Location: Highbury Grove junction with Highbury New Park
#   Vehicles Involved: BusOrCoach
#   Casualties:
#     - Age: 15, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Child
#
# --------------------------------------------------
#
# Fatal Incident 404:
#   Date: 15 November 2005, 09:15 AM
#   Borough: Islington
#   Location: Hornsey Rise junction with Cromartie Road
#   Vehicles Involved: PedalCycle, LightGoodsVehicle
#   Casualties:
#     - Age: 30, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 405:
#   Date: 18 November 2005, 07:27 AM
#   Borough: Islington
#   Location: Clerkenwell Road junction with St John Street
#   Vehicles Involved: PedalCycle, HeavyGoodsVehicle
#   Casualties:
#     - Age: 37, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 406:
#   Date: 02 December 2005, 05:15 PM
#   Borough: Hackney
#   Location: Amhurst Park 90 metres south east of junction with Rav Pinter Close
#   Vehicles Involved: OtherMotorVehicle, Car
#   Casualties:
#     - Age: 84, Class: Driver, Severity: Fatal, Mode: OtherVehicle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 407:
#   Date: 15 December 2005, 08:45 PM
#   Borough: Hackney
#   Location: Bodney Road 50 metres south west of junction with Downs Park Road
#   Vehicles Involved: Car
#   Casualties:
#     - Age: 5, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Child
#
# --------------------------------------------------
#
# Fatal Incident 408:
#   Date: 20 July 2005, 08:05 PM
#   Borough: Hackney
#   Location: Homerton High Street junction with Ponsford Street
#   Vehicles Involved: Car, PedalCycle
#   Casualties:
#     - Age: 32, Class: Driver, Severity: Fatal, Mode: PedalCycle, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 409:
#   Date: 12 September 2005, 10:31 AM
#   Borough: Hackney
#   Location: Green Lanes 21 metres north junction with Leconfield Road
#   Vehicles Involved: Motorcycle_125_500cc
#   Casualties:
#     - Age: 19, Class: Driver, Severity: Slight, Mode: PoweredTwoWheeler, Age Band: Adult
#     - Age: 32, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------
#
# Fatal Incident 410:
#   Date: 20 February 2005, 03:10 PM
#   Borough: Tower Hamlets
#   Location: Mile End Road junction with Assembly Passage
#   Vehicles Involved: PedalCycle
#   Casualties:
#     - Age: 26, Class: Driver, Severity: Slight, Mode: PedalCycle, Age Band: Adult
#     - Age: 42, Class: Pedestrian, Severity: Fatal, Mode: Pedestrian, Age Band: Adult
#
# --------------------------------------------------

# %%
from collections import Counter

# Count fatalities per borough
fatalities_per_borough = Counter(incident['borough'] for incident in fatal_incidents)

# Display boroughs ranked by fatalities
print("Fatalities per Borough (Highest to Lowest):\n")

# Determine the maximum width for borough names for alignment
max_borough_width = max(len(borough) for borough in fatalities_per_borough)

# Print the fatalities per borough with proper alignment
for borough, count in fatalities_per_borough.most_common():  # Sorted in descending order
    print(f"{borough:{max_borough_width}}: {count} Fatal Incidents")
# Out:
# Fatalities per Borough (Highest to Lowest):
#
# Hounslow              : 26 Fatal Incidents
# Enfield               : 24 Fatal Incidents
# Barnet                : 24 Fatal Incidents
# City of Westminster   : 22 Fatal Incidents
# Hammersmith and Fulham: 20 Fatal Incidents
# Kensington and Chelsea: 20 Fatal Incidents
# Bromley               : 18 Fatal Incidents
# Tower Hamlets         : 16 Fatal Incidents
# Ealing                : 16 Fatal Incidents
# Lambeth               : 16 Fatal Incidents
# Hillingdon            : 14 Fatal Incidents
# Brent                 : 14 Fatal Incidents
# Redbridge             : 14 Fatal Incidents
# Croydon               : 14 Fatal Incidents
# Haringey              : 14 Fatal Incidents
# Greenwich             : 14 Fatal Incidents
# Bexley                : 12 Fatal Incidents
# Havering              : 12 Fatal Incidents
# Barking and Dagenham  : 12 Fatal Incidents
# Lewisham              : 12 Fatal Incidents
# Southwark             : 10 Fatal Incidents
# Waltham Forest        : 10 Fatal Incidents
# Islington             : 8 Fatal Incidents
# Wandsworth            : 8 Fatal Incidents
# Hackney               : 8 Fatal Incidents
# Kingston              : 6 Fatal Incidents
# Harrow                : 6 Fatal Incidents
# Camden                : 4 Fatal Incidents
# Newham                : 4 Fatal Incidents
# Richmond upon Thames  : 4 Fatal Incidents
# Sutton                : 4 Fatal Incidents
# City of London        : 2 Fatal Incidents
# Merton                : 2 Fatal Incidents

# %%
from collections import Counter
from datetime import datetime

# Extract hours from fatal incidents (handling 'Z' in timestamp)
fatal_hours = [datetime.fromisoformat(incident['date'].replace("Z", "")).hour for incident in fatal_incidents]

# Count occurrences of each hour
hourly_fatalities = Counter(fatal_hours)

# Display peak hours sorted by most incidents
print("Peak Hours for Fatal Accidents:\n")

# Find the most common hour (peak hour)
most_common_hour, most_common_count = hourly_fatalities.most_common(1)[0]

# Find the maximum width for time slots (to align them)
max_hour_width = max(len(f"{hour}:00") for hour in hourly_fatalities.keys())

# Print the most common hour first
start_time = f"{most_common_hour}:00"
end_time = f"{most_common_hour + 1}:00"
print(f"Most Common Hour: {start_time} → {end_time} → {most_common_count} Fatal Incidents\n")

# Print the fatal incidents in a neat format for all hours, sorted by incidents
for hour, count in sorted(hourly_fatalities.items(), key=lambda x: x[1], reverse=True):
    start_time = f"{hour}:00"
    end_time = f"{hour + 1}:00"
    print(f"{start_time:{max_hour_width}} → {end_time} → {count} Fatal Incidents")
# Out:
# Peak Hours for Fatal Accidents:
#
# Most Common Hour: 17:00 → 18:00 → 36 Fatal Incidents
#
# 17:00 → 18:00 → 36 Fatal Incidents
# 18:00 → 19:00 → 34 Fatal Incidents
# 22:00 → 23:00 → 24 Fatal Incidents
# 0:00  → 1:00 → 22 Fatal Incidents
# 21:00 → 22:00 → 22 Fatal Incidents
# 13:00 → 14:00 → 22 Fatal Incidents
# 10:00 → 11:00 → 22 Fatal Incidents
# 15:00 → 16:00 → 20 Fatal Incidents
# 20:00 → 21:00 → 20 Fatal Incidents
# 12:00 → 13:00 → 18 Fatal Incidents
# 1:00  → 2:00 → 18 Fatal Incidents
# 19:00 → 20:00 → 18 Fatal Incidents
# 9:00  → 10:00 → 18 Fatal Incidents
# 16:00 → 17:00 → 16 Fatal Incidents
# 8:00  → 9:00 → 14 Fatal Incidents
# 7:00  → 8:00 → 14 Fatal Incidents
# 23:00 → 24:00 → 12 Fatal Incidents
# 2:00  → 3:00 → 12 Fatal Incidents
# 11:00 → 12:00 → 12 Fatal Incidents
# 6:00  → 7:00 → 10 Fatal Incidents
# 4:00  → 5:00 → 8 Fatal Incidents
# 5:00  → 6:00 → 8 Fatal Incidents
# 14:00 → 15:00 → 8 Fatal Incidents
# 3:00  → 4:00 → 2 Fatal Incidents

# %%
from collections import Counter
from datetime import datetime

# Extract days of the week (handling 'Z' in timestamp)
fatal_days = [datetime.fromisoformat(incident['date'].replace("Z", "")).strftime('%A') for incident in fatal_incidents]

# Count occurrences per day
daily_fatalities = Counter(fatal_days)

# Define the order of days of the week
weekdays_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Identify the most common day
most_common_day, most_common_count = daily_fatalities.most_common(1)[0]

# Display peak days sorted by most incidents
print("\nPeak Days for Fatal Accidents:\n")

# Print the most common day
print(f"Most Common Day: {most_common_day} with {most_common_count} fatal incidents\n")

# Sort the days according to the predefined weekday order
for day in weekdays_order:
    count = daily_fatalities.get(day, 0)  # Get the count or 0 if not found
    print(f"{day:10}: {count} fatal incidents")
# Out:
# Peak Days for Fatal Accidents:
#
# Most Common Day: Thursday with 76 fatal incidents
#
# Monday    : 44 fatal incidents
# Tuesday   : 50 fatal incidents
# Wednesday : 72 fatal incidents
# Thursday  : 76 fatal incidents
# Friday    : 62 fatal incidents
# Saturday  : 54 fatal incidents
# Sunday    : 52 fatal incidents

# %%
from collections import Counter
from datetime import datetime

# Extract month names (handling 'Z' in timestamp)
fatal_months = [datetime.fromisoformat(incident['date'].replace("Z", "")).strftime('%B') for incident in fatal_incidents]

# Count occurrences per month
monthly_fatalities = Counter(fatal_months)

# Define the order of months
months_order = [
    'January', 'February', 'March', 'April', 'May', 'June', 
    'July', 'August', 'September', 'October', 'November', 'December'
]

# Identify the most common month
most_common_month, most_common_count = monthly_fatalities.most_common(1)[0]

# Display peak months sorted by most incidents
print("\nPeak Months for Fatal Accidents:\n")

# Print the most common month
print(f"Most Common Month: {most_common_month} with {most_common_count} fatal incidents\n")

# Sort the months according to the predefined month order
for month in months_order:
    count = monthly_fatalities.get(month, 0)  # Get the count or 0 if not found
    print(f"{month:9}: {count} fatal incidents")
# Out:
# Peak Months for Fatal Accidents:
#
# Most Common Month: November with 52 fatal incidents
#
# January  : 20 fatal incidents
# February : 22 fatal incidents
# March    : 36 fatal incidents
# April    : 18 fatal incidents
# May      : 26 fatal incidents
# June     : 42 fatal incidents
# July     : 40 fatal incidents
# August   : 28 fatal incidents
# September: 36 fatal incidents
# October  : 42 fatal incidents
# November : 52 fatal incidents
# December : 48 fatal incidents

# %%
# Incomplete Data Overview.
# a) Counts by Class
class_counts = incomplete_df['class'].value_counts()
print("\nClass Distribution:")
separator = "=" * 50
print(separator)  # Separator for better visibility
print(f"{'Class': <20} {'Incidents': >10}")
print("-" * 50)  # Separator between header and data
for class_name, count in class_counts.items():
    print(f"{class_name:<20} {count:>10,} incidents")  # Added comma separator for large numbers

# b) Counts by Severity
severity_counts = incomplete_df['severity'].value_counts()
print("\nSeverity Distribution:")
print(separator)
print(f"{'Severity': <10} {'Incidents': >10}")
print("-" * 50)
for severity, count in severity_counts.items():
    print(f"{severity:<10} {count:>10,} incidents")

# c) Age Band Distribution
age_band_counts = incomplete_df['ageBand'].value_counts()
print("\nAge Band Distribution:")
print(separator)
print(f"{'Age Band': <15} {'Casualties': >10}")
print("-" * 50)
for age_band, count in age_band_counts.items():
    print(f"{age_band:<15} {count:>10,} casualties")

# d) Mode Distribution (Optional)
mode_counts = incomplete_df['mode'].value_counts()
print("\nMode Distribution:")
print(separator)
print(f"{'Mode': <20} {'Incidents': >10}")
print("-" * 50)
for mode, count in mode_counts.items():
    print(f"{mode:<20} {count:>10,} incidents")
# Out:
# Class Distribution:
# ==================================================
# Class                 Incidents
# --------------------------------------------------
# Passenger                 2,436 incidents
# Driver                    1,876 incidents
# Pedestrian                  850 incidents
#
# Severity Distribution:
# ==================================================
# Severity    Incidents
# --------------------------------------------------
# Slight          4,702 incidents
# Serious           460 incidents
#
# Age Band Distribution:
# ==================================================
# Age Band        Casualties
# --------------------------------------------------
# Unknown              5,110 casualties
# Child                   52 casualties
#
# Mode Distribution:
# ==================================================
# Mode                  Incidents
# --------------------------------------------------
# Car                       2,588 incidents
# Pedestrian                  850 incidents
# PoweredTwoWheeler           516 incidents
# BusOrCoach                  486 incidents
# PedalCycle                  476 incidents
# OtherVehicle                106 incidents
# GoodsVehicle                 92 incidents
# Taxi                         48 incidents
